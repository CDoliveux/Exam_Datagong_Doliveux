# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\chd78002\\OneDrive - Groupe IPSEN\\Documents\\GIT-PROJECTS\\Exam_Datagong_Doliveux\\notebooks'

# %%
import pandas as pd

# %%
#Import du fichier
df=pd.read_csv("../data/thelook_fr_women_2023_2024.csv")

# %%
# Affichez les dimensions du DataFrame
print(f"La base fait {df.shape[0]} lignes et {df.shape[1]} colonnes")
# Out:
# La base fait 1679 lignes et 20 colonnes

# %% [markdown]
# # PARTIE 1 : ANALYSE DU DATAFRAME, CONTROLE QUALITE, FORMATTAGE DES DATES, COHERENCES DES DONNEES"

# %%
# Affichez les 5 premières lignes
df.head()
# Out:
#    order_id  order_item_id  product_id            item_created_at item_status  \
# 0     19425          28112        6983  2023-01-01 06:18:03+00:00     Shipped
# 1     19425          28113       10597  2023-01-01 06:44:58+00:00     Shipped
# 2      4710           6730       11792  2023-01-03 04:44:50+00:00    Complete
# 3     16618          24006         329  2023-01-03 15:13:39+00:00    Complete
# 4      4710           6731        5295  2023-01-05 06:43:09+00:00    Complete
#
#    sale_price       cost        category department                   brand  \
# 0   29.500000  16.048000          Shorts      Women                     Fox
# 1   20.000000  10.000000       Intimates      Women                  Wacoal
# 2   38.000000  18.468000       Intimates      Women        American Apparel
# 3   27.990000  16.402140     Tops & Tees      Women            Tri-Mountain
# 4   56.880001  29.577601  Pants & Capris      Women  Lauren by Ralph Lauren
#
#                                         product_name order_status  \
# 0                         Fox Juniors Momentum Short      Shipped
# 1                   Wacoal Women's B-Smooth Bralette      Shipped
# 2              American Apparel Striped Chiffon Tank     Complete
# 3  Tri-Mountain Women's 3/4-Sleeve Pique Knit Pol...     Complete
# 4                   Lauren Ralph Lauren Velour Pants     Complete
#
#             order_created_at                 shipped_at  \
# 0  2022-12-29 10:00:00+00:00  2022-12-30 11:29:00+00:00
# 1  2022-12-29 10:00:00+00:00  2022-12-30 11:29:00+00:00
# 2  2023-01-03 08:12:00+00:00  2023-01-03 09:14:00+00:00
# 3  2023-01-03 18:58:00+00:00  2023-01-05 13:23:00+00:00
# 4  2023-01-03 08:12:00+00:00  2023-01-03 09:14:00+00:00
#
#                 delivered_at  user_id gender country                state  \
# 0                        NaN    15644      F  France  Centre-Val de Loire
# 1                        NaN    15644      F  France  Centre-Val de Loire
# 2  2023-01-04 03:03:00+00:00     3853      F  France        Île-de-France
# 3  2023-01-09 10:25:00+00:00    13422      F  France      Hauts-de-France
# 4  2023-01-04 03:03:00+00:00     3853      F  France        Île-de-France
#
#            city
# 0  Corquilleroy
# 1  Corquilleroy
# 2         Paris
# 3       Comines
# 4         Paris

# %%
# Utilisation de la méthode info
df.info()
pd.set_option('display.max_rows', None)
ville_region_unique = df[["city", "state"]].drop_duplicates()
df_sorted = ville_region_unique.sort_values(by="city")
df_sorted
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1679 entries, 0 to 1678
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1679 non-null   int64
#  1   order_item_id     1679 non-null   int64
#  2   product_id        1679 non-null   int64
#  3   item_created_at   1679 non-null   object
#  4   item_status       1679 non-null   object
#  5   sale_price        1679 non-null   float64
#  6   cost              1679 non-null   float64
#  7   category          1679 non-null   object
#  8   department        1679 non-null   object
#  9   brand             1677 non-null   object
#  10  product_name      1679 non-null   object
#  11  order_status      1679 non-null   object
#  12  order_created_at  1679 non-null   object
#  13  shipped_at        1133 non-null   object
#  14  delivered_at      636 non-null    object
#  15  user_id           1679 non-null   int64
#  16  gender            1679 non-null   object
#  17  country           1679 non-null   object
#  18  state             1679 non-null   object
#  19  city              1679 non-null   object
# dtypes: float64(2), int64(4), object(14)
# memory usage: 262.5+ KB
#                              city                       state
# 1460                      Achères               Île-de-France
# 8                            Agen          Nouvelle-Aquitaine
# 970                        Agnetz             Hauts-de-France
# 110                       Aiffres          Nouvelle-Aquitaine
# 626                     Aigaliers                   Occitanie
# 1039                 Aix-Noulette             Hauts-de-France
# 830               Aix-en-Provence  Provence-Alpes-Côte d'Azur
# 822                       Ajaccio                       Corse
# 627                          Albi                   Occitanie
# 1230                      Alençon                   Normandie
# 227                   Alfortville               Île-de-France
# 52                         Amiens             Hauts-de-France
# 449                        Amilly         Centre-Val de Loire
# 596                       Andrésy               Île-de-France
# 862                        Angers            Pays de la Loire
# 111                     Angoulême          Nouvelle-Aquitaine
# 754                        Annecy        Auvergne-Rhône-Alpes
# 373                      Anneyron        Auvergne-Rhône-Alpes
# 461                          Anse        Auvergne-Rhône-Alpes
# 610                       Antibes  Provence-Alpes-Côte d'Azur
# 952                        Antony               Île-de-France
# 237                      Appietto                       Corse
# 10                      Arcangues          Nouvelle-Aquitaine
# 513                       Arcueil               Île-de-France
# 995                         Ardon         Centre-Val de Loire
# 452                    Argenteuil               Île-de-France
# 288                         Arles  Provence-Alpes-Côte d'Azur
# 1655                        Arnas        Auvergne-Rhône-Alpes
# 1613             Arpajon-sur-Cère        Auvergne-Rhône-Alpes
# 910                   Arpheuilles         Centre-Val de Loire
# 48                          Arras             Hauts-de-France
# 56                          Arsac          Nouvelle-Aquitaine
# 895                    Athis-Mons               Île-de-France
# 1429          Athis-Val-de-Rouvre                   Normandie
# 1556               Athée-sur-Cher         Centre-Val de Loire
# 1095                      Aubagne  Provence-Alpes-Côte d'Azur
# 1484                Aubervilliers               Île-de-France
# 313                          Auch                   Occitanie
# 984              Aulnay-sous-Bois               Île-de-France
# 808                      Aurillac        Auvergne-Rhône-Alpes
# 912                        Auriol  Provence-Alpes-Côte d'Azur
# 968                      Aussonne                   Occitanie
# 260                       Auxonne     Bourgogne-Franche-Comté
# 1674           Avant-lès-Marcilly                   Grand Est
# 594                       Avignon  Provence-Alpes-Côte d'Azur
# 62            Avignonet-Lauragais                   Occitanie
# 854                         Avion             Hauts-de-France
# 1075                          Azé         Centre-Val de Loire
# 40                        Bagneux               Île-de-France
# 930              Bain-de-Bretagne                    Bretagne
# 145                Baugé en Anjou            Pays de la Loire
# 394                    Beausoleil  Provence-Alpes-Côte d'Azur
# 1259             Beautheil-Saints               Île-de-France
# 1170                      Belfort     Bourgogne-Franche-Comté
# 158            Bellefont-La Rauze                   Occitanie
# 1441     Belleville-en-Beaujolais        Auvergne-Rhône-Alpes
# 1645                        Benon          Nouvelle-Aquitaine
# 1190      Berchères-Saint-Germain         Centre-Val de Loire
# 805                      Besançon     Bourgogne-Franche-Comté
# 404                    Beuzeville                   Normandie
# 944                   Biscarrosse          Nouvelle-Aquitaine
# 641                   Bischwiller                   Grand Est
# 758                   Blanquefort          Nouvelle-Aquitaine
# 266                         Blois         Centre-Val de Loire
# 246                 Bois-Colombes               Île-de-France
# 325            Boissy-Saint-Léger               Île-de-France
# 156                         Bondy               Île-de-France
# 144             Bonneuil-les-Eaux             Hauts-de-France
# 137            Bonneuil-sur-Marne               Île-de-France
# 66                       Bordeaux          Nouvelle-Aquitaine
# 1060        Boulazac Isle Manoire          Nouvelle-Aquitaine
# 879          Boulogne-Billancourt               Île-de-France
# 1165             Boulogne-sur-Mer             Hauts-de-France
# 587                       Bourges         Centre-Val de Loire
# 1342     Bourneville-Sainte-Croix                   Normandie
# 957                        Bousse                   Grand Est
# 843                    Bressolles        Auvergne-Rhône-Alpes
# 208                         Brest                    Bretagne
# 1624            Brie-Comte-Robert               Île-de-France
# 1442                    Brignoles  Provence-Alpes-Côte d'Azur
# 166            Brive-la-Gaillarde          Nouvelle-Aquitaine
# 748              Brié-et-Angonnes        Auvergne-Rhône-Alpes
# 179                          Bron        Auvergne-Rhône-Alpes
# 1454           Bruay-la-Buissière             Hauts-de-France
# 521                       Brumath                   Grand Est
# 674                          Bruz                    Bretagne
# 113           Bréal-sous-Montfort                    Bretagne
# 628                       Bréauté                   Normandie
# 58                         Bulles             Hauts-de-France
# 384                          Bury             Hauts-de-France
# 499                        Bègles          Nouvelle-Aquitaine
# 348            Bézaudun-les-Alpes  Provence-Alpes-Côte d'Azur
# 24                        Béziers                   Occitanie
# 161              Caluire-et-Cuire        Auvergne-Rhône-Alpes
# 1086                      Cambrai             Hauts-de-France
# 1241                    Campénéac                    Bretagne
# 670                        Cannes  Provence-Alpes-Côte d'Azur
# 661                   Carcassonne                   Occitanie
# 1414                   Carpentras  Provence-Alpes-Côte d'Azur
# 370           Carrières-sur-Seine               Île-de-France
# 1551                       Carvin             Hauts-de-France
# 1145             Castanet-Tolosan                   Occitanie
# 104            Castelnau-de-Lévis                   Occitanie
# 846              Castelnau-le-Lez                   Occitanie
# 43                        Castres                   Occitanie
# 896                      Castries                   Occitanie
# 450                         Cenon          Nouvelle-Aquitaine
# 868                         Cergy               Île-de-France
# 403                        Cernay                   Grand Est
# 216                Cesson-Sévigné                    Bretagne
# 1253                       Cestas          Nouvelle-Aquitaine
# 580                   Chamalières        Auvergne-Rhône-Alpes
# 1427                  Champagnier        Auvergne-Rhône-Alpes
# 716           Champigny-sur-Marne               Île-de-France
# 1018                     Chanteau         Centre-Val de Loire
# 915                  Chapareillan        Auvergne-Rhône-Alpes
# 1067         Charleville-Mézières                   Grand Est
# 148                        Chatou               Île-de-France
# 608             Chaumont-en-Vexin             Hauts-de-France
# 233                       Chelles               Île-de-France
# 1174   Chenac-Saint-Seurin-d'Uzet          Nouvelle-Aquitaine
# 1014           Chenoise-Cucharmoy               Île-de-France
# 376         Cherbourg-en-Cotentin                   Normandie
# 70                 Chevilly-Larue               Île-de-France
# 1274                       Choisy        Auvergne-Rhône-Alpes
# 755                       Châbons        Auvergne-Rhône-Alpes
# 1564  Château-Gontier-sur-Mayenne            Pays de la Loire
# 117               Château-Thébaud            Pays de la Loire
# 133         Châteauneuf-sur-Isère        Auvergne-Rhône-Alpes
# 1544        Châteauneuf-sur-Loire         Centre-Val de Loire
# 254                 Châteaurenard  Provence-Alpes-Côte d'Azur
# 235                   Châteauroux         Centre-Val de Loire
# 713          Châtel-Saint-Germain                   Grand Est
# 1355             Châtenay-Malabry               Île-de-France
# 553                     Châtillon               Île-de-France
# 692                   Clairmarais             Hauts-de-France
# 975                 Claye-Souilly               Île-de-France
# 253              Clermont-Ferrand        Auvergne-Rhône-Alpes
# 921            Clermont-l'Hérault                   Occitanie
# 1653                       Clichy               Île-de-France
# 304               Cléry-sur-Somme             Hauts-de-France
# 1269                       Cognac          Nouvelle-Aquitaine
# 277                       Collias                   Occitanie
# 511                        Colmar                   Grand Est
# 259                      Colombes               Île-de-France
# 3                         Comines             Hauts-de-France
# 642                   Commequiers            Pays de la Loire
# 623                     Compiègne             Hauts-de-France
# 1649             Corbeil-Essonnes               Île-de-France
# 470                        Corbie             Hauts-de-France
# 0                    Corquilleroy         Centre-Val de Loire
# 478                      Coupvray               Île-de-France
# 353                    Courbevoie               Île-de-France
# 84             Cournon-d'Auvergne        Auvergne-Rhône-Alpes
# 1447                    Courtenay        Auvergne-Rhône-Alpes
# 1183                      Couëron            Pays de la Loire
# 26                        Créteil               Île-de-France
# 1227                          Dax          Nouvelle-Aquitaine
# 312                Deuil-la-Barre               Île-de-France
# 209                        Dieppe                   Normandie
# 198                         Dijon     Bourgogne-Franche-Comté
# 355                    Dorlisheim                   Grand Est
# 714                         Douai             Hauts-de-France
# 430                 Doué-en-Anjou            Pays de la Loire
# 978                    Draguignan  Provence-Alpes-Côte d'Azur
# 1440                      Draveil               Île-de-France
# 1621                     Eaubonne               Île-de-France
# 126          Ennetières-en-Weppes             Hauts-de-France
# 933                        Erbray            Pays de la Loire
# 151                       Erstein                   Grand Est
# 114                 Esmery-Hallon             Hauts-de-France
# 18              Essômes-sur-Marne             Hauts-de-France
# 1568                  Eyzin-Pinet        Auvergne-Rhône-Alpes
# 1208                     Favières               Île-de-France
# 1405                        Feneu            Pays de la Loire
# 471              Fontaine-Chaalis             Hauts-de-France
# 1078                      Forbach                   Grand Est
# 268                        Frencq             Hauts-de-France
# 651                       Fresnes               Île-de-France
# 7                      Frontignan                   Occitanie
# 964                        Fécamp                   Normandie
# 74                          Gagny               Île-de-France
# 357                       Gaillac                   Occitanie
# 1455                     Gaillard        Auvergne-Rhône-Alpes
# 428         Gaillon-sur-Montcient               Île-de-France
# 1221                      Garches               Île-de-France
# 1333                       Gazost                   Occitanie
# 941                 Gennevilliers               Île-de-France
# 20                           Gien         Centre-Val de Loire
# 55           Glières-Val-de-Borne        Auvergne-Rhône-Alpes
# 215                       Gonesse               Île-de-France
# 480                        Gourgé          Nouvelle-Aquitaine
# 689                     Gradignan          Nouvelle-Aquitaine
# 1528                  Grand-Champ                    Bretagne
# 98                         Grasse  Provence-Alpes-Côte d'Azur
# 828                       Grenade                   Occitanie
# 654                      Grenoble        Auvergne-Rhône-Alpes
# 383                 Guichainville                   Normandie
# 1282                      Guignen                    Bretagne
# 1582                     Guipavas                    Bretagne
# 152                    Guyancourt               Île-de-France
# 1618                     Habsheim                   Grand Est
# 1113                     Haguenau                   Grand Est
# 54                        Hanches         Centre-Val de Loire
# 876                     Hasparren          Nouvelle-Aquitaine
# 779                     Herbignac            Pays de la Loire
# 1300                       Hirson             Hauts-de-France
# 13                       Honfleur                   Normandie
# 476                        Hyères  Provence-Alpes-Côte d'Azur
# 1545       Hérouville-Saint-Clair                   Normandie
# 582                      Illfurth                   Grand Est
# 315        Illkirch-Graffenstaden                   Grand Est
# 1522                        Ingré         Centre-Val de Loire
# 1210          Issy-les-Moulineaux               Île-de-France
# 928                Ivry-sur-Seine               Île-de-France
# 95                         Izeaux        Auvergne-Rhône-Alpes
# 707                      Jebsheim                   Grand Est
# 168                          Joux        Auvergne-Rhône-Alpes
# 82                 Joué-lès-Tours         Centre-Val de Loire
# 504                     Kervignac                    Bretagne
# 1006              L'Haÿ-les-Roses               Île-de-France
# 489             L'Île-Saint-Denis               Île-de-France
# 637          La Celle-Saint-Cloud               Île-de-France
# 832                La Champenoise         Centre-Val de Loire
# 803                     La Ciotat  Provence-Alpes-Côte d'Azur
# 393                  La Courneuve               Île-de-France
# 609                     La Flèche            Pays de la Loire
# 364            La Grande-Paroisse               Île-de-France
# 1080    La Neuville-Chant-d'Oisel                   Normandie
# 303            La Neuville-en-Hez             Hauts-de-France
# 1275           La Roche-sur-Foron        Auvergne-Rhône-Alpes
# 522              La Roche-sur-Yon            Pays de la Loire
# 1063         La Selle-sur-le-Bied         Centre-Val de Loire
# 354              La Seyne-sur-Mer  Provence-Alpes-Côte d'Azur
# 1278                La Séguinière            Pays de la Loire
# 454              La Tour-d'Aigues  Provence-Alpes-Côte d'Azur
# 958             La Valette-du-Var  Provence-Alpes-Côte d'Azur
# 1456              Laines-aux-Bois                   Grand Est
# 378                Lamballe-Armor                    Bretagne
# 31                           Laon             Hauts-de-France
# 429                       Laplume          Nouvelle-Aquitaine
# 572                        Lattes                   Occitanie
# 549                         Laval            Pays de la Loire
# 437                      Laventie             Hauts-de-France
# 360                 Le Bas-Ségala                   Occitanie
# 107               Le Blanc-Mesnil               Île-de-France
# 971                    Le Bouscat          Nouvelle-Aquitaine
# 195                     Le Cannet  Provence-Alpes-Côte d'Azur
# 369                  Le Castellet  Provence-Alpes-Côte d'Azur
# 768       Le Chesnay-Rocquencourt               Île-de-France
# 1261       Le Controis-en-Sologne         Centre-Val de Loire
# 193                  Le Fidelaire                   Normandie
# 5                        Le Havre                   Normandie
# 469            Le Kremlin-Bicêtre               Île-de-France
# 451                       Le Mans            Pays de la Loire
# 199         Le Mesnil-Saint-Denis               Île-de-France
# 999                     Le Pertre                    Bretagne
# 1286          Le Plessis-Robinson               Île-de-France
# 339            Le Plessis-Trévise               Île-de-France
# 1320                    Le Raincy               Île-de-France
# 1315      Le Sappey-en-Chartreuse        Auvergne-Rhône-Alpes
# 157                      Le Teich          Nouvelle-Aquitaine
# 667                   Les Deserts        Auvergne-Rhône-Alpes
# 1301                    Les Lilas               Île-de-France
# 129                   Les Mureaux               Île-de-France
# 1204          Les Sables-d'Olonne            Pays de la Loire
# 953                      Les Ulis               Île-de-France
# 424                    Les Ventes                   Normandie
# 1109             Levallois-Perret               Île-de-France
# 491                        Leymen                   Grand Est
# 247                      Libourne          Nouvelle-Aquitaine
# 1470                        Ligné            Pays de la Loire
# 41                          Lille             Hauts-de-France
# 1375                   Lillebonne                   Normandie
# 1047                      Lillers             Hauts-de-France
# 50                        Limoges          Nouvelle-Aquitaine
# 592                Livet-et-Gavet        Auvergne-Rhône-Alpes
# 468                         Locon             Hauts-de-France
# 279                 Loire-Authion            Pays de la Loire
# 1566              Longues-sur-Mer                   Normandie
# 283                          Lons          Nouvelle-Aquitaine
# 327                       Lorient                    Bretagne
# 28                       Louviers                   Normandie
# 497                          Lure     Bourgogne-Franche-Comté
# 704                     Luzarches               Île-de-France
# 173                          Lyon        Auvergne-Rhône-Alpes
# 382                      Léogeats          Nouvelle-Aquitaine
# 25             Lézignan-Corbières                   Occitanie
# 340                Maisons-Alfort               Île-de-France
# 1270                     Malakoff               Île-de-France
# 278                Malay-le-Grand     Bourgogne-Franche-Comté
# 1040                     Malville            Pays de la Loire
# 37           Mandelieu-la-Napoule  Provence-Alpes-Côte d'Azur
# 286                        Marans          Nouvelle-Aquitaine
# 1430                 Marckolsheim                   Grand Est
# 202               Marcq-en-Barœul             Hauts-de-France
# 112               Marey-sur-Tille     Bourgogne-Franche-Comté
# 432                      Marquise             Hauts-de-France
# 94                      Marseille  Provence-Alpes-Côte d'Azur
# 1360                        Massy               Île-de-France
# 106                       Mauguio                   Occitanie
# 46                      Mazaugues  Provence-Alpes-Côte d'Azur
# 1516             Mercurol-Veaunes        Auvergne-Rhône-Alpes
# 387                       Mercury        Auvergne-Rhône-Alpes
# 599                          Metz                   Grand Est
# 406                        Meudon               Île-de-France
# 1129                         Mios          Nouvelle-Aquitaine
# 1340               Mons-en-Barœul             Hauts-de-France
# 1371              Montaigu-Vendée            Pays de la Loire
# 123                    Montarnaud                   Occitanie
# 375                   Montfermeil               Île-de-France
# 368                 Montierchaume         Centre-Val de Loire
# 267        Montigny-le-Bretonneux               Île-de-France
# 294             Montigny-lès-Metz                   Grand Est
# 1008                Montivilliers                   Normandie
# 1385                     Montluel        Auvergne-Rhône-Alpes
# 1187                    Montmagny               Île-de-France
# 568                   Montpellier                   Occitanie
# 258                     Montreuil               Île-de-France
# 1281         Montrevault-sur-Èvre            Pays de la Loire
# 529                     Montrouge               Île-de-France
# 929                    Montélimar        Auvergne-Rhône-Alpes
# 1216                       Mornac          Nouvelle-Aquitaine
# 698       Mouliets-et-Villemartin          Nouvelle-Aquitaine
# 276                Mozé-sur-Louet            Pays de la Loire
# 1436                     Mulhouse                   Grand Est
# 1222                        Mâcon     Bourgogne-Franche-Comté
# 308                      Mérignac          Nouvelle-Aquitaine
# 81                       Nanterre               Île-de-France
# 234                        Nantes            Pays de la Loire
# 650                      Narbonne                   Occitanie
# 1184            Neuilly-Plaisance               Île-de-France
# 374                          Nice  Provence-Alpes-Côte d'Azur
# 9                           Niort          Nouvelle-Aquitaine
# 1211             Nogent-sur-Marne               Île-de-France
# 1513               Noisy-le-Grand               Île-de-France
# 589                Noroy-le-Bourg     Bourgogne-Franche-Comté
# 275    Noyal-Châtillon-sur-Seiche                    Bretagne
# 63                          Noyon             Hauts-de-France
# 530                         Néron         Centre-Val de Loire
# 818                         Nîmes                   Occitanie
# 184                       Obernai                   Grand Est
# 559                        Orange  Provence-Alpes-Côte d'Azur
# 1011                      Orléans         Centre-Val de Loire
# 1126                       Orthez          Nouvelle-Aquitaine
# 333                          Osny               Île-de-France
# 175                       Outreau             Hauts-de-France
# 72                        Oyonnax        Auvergne-Rhône-Alpes
# 664                     Palaiseau               Île-de-France
# 1377                       Pantin               Île-de-France
# 1125          Paray-Vieille-Poste               Île-de-France
# 2                           Paris               Île-de-France
# 12                            Pau          Nouvelle-Aquitaine
# 310                 Perdreauville               Île-de-France
# 973                     Perpignan                   Occitanie
# 1045                       Pessac          Nouvelle-Aquitaine
# 309           Pithiviers-le-Vieil         Centre-Val de Loire
# 273                     Plabennec                    Bretagne
# 639                      Ploemeur                    Bretagne
# 93        Plogastel-Saint-Germain                    Bretagne
# 101                    Ploufragan                    Bretagne
# 1122                 Plounéventer                    Bretagne
# 316           Plourin-lès-Morlaix                    Bretagne
# 329                     Plumergat                    Bretagne
# 361                        Plérin                    Bretagne
# 1593                       Poissy               Île-de-France
# 849                      Poitiers          Nouvelle-Aquitaine
# 1606          Pommerit-le-Vicomte                    Bretagne
# 262                      Pomponne               Île-de-France
# 980                     Pontpoint             Hauts-de-France
# 961           Porte-des-Bonnevaux        Auvergne-Rhône-Alpes
# 192                      Précigné            Pays de la Loire
# 1666                      Puteaux               Île-de-France
# 721                     Périgueux          Nouvelle-Aquitaine
# 815                       Pézenas                   Occitanie
# 51                        Quimper                    Bretagne
# 363                         Reims                   Grand Est
# 130                        Rennes                    Bretagne
# 1580                        Revel        Auvergne-Rhône-Alpes
# 508                      Reyrieux        Auvergne-Rhône-Alpes
# 236                          Rezé            Pays de la Loire
# 1319                      Rieumes                   Occitanie
# 16               Rillieux-la-Pape        Auvergne-Rhône-Alpes
# 154                   Ris-Orangis               Île-de-France
# 155                Rives-de-l'Yon            Pays de la Loire
# 218        Rivière-Saas-et-Gourby          Nouvelle-Aquitaine
# 1059                        Roche        Auvergne-Rhône-Alpes
# 1152                 Rochecolombe        Auvergne-Rhône-Alpes
# 1536                        Rodez                   Occitanie
# 1656             Romans-sur-Isère        Auvergne-Rhône-Alpes
# 490                       Ronchin             Hauts-de-France
# 389                        Rouans            Pays de la Loire
# 67                        Roubaix             Hauts-de-France
# 515                         Rouen                   Normandie
# 1352                      Rouvroy             Hauts-de-France
# 562               Rueil-Malmaison               Île-de-France
# 1263                       Saclay               Île-de-France
# 456         Saint-André-de-Cubzac          Nouvelle-Aquitaine
# 799        Saint-Antoine-l'Abbaye        Auvergne-Rhône-Alpes
# 346                   Saint-Avold                   Grand Est
# 203        Saint-Brice-sous-Forêt               Île-de-France
# 143                 Saint-Chamond        Auvergne-Rhône-Alpes
# 1560                  Saint-Cloud               Île-de-France
# 886             Saint-Cyr-l'École               Île-de-France
# 752                   Saint-Denis               Île-de-France
# 356       Saint-Didier-de-la-Tour        Auvergne-Rhône-Alpes
# 759                  Saint-Dizier                   Grand Est
# 1570         Saint-Dié-des-Vosges                   Grand Est
# 1175                  Saint-Désir                   Normandie
# 483                  Saint-Estève                   Occitanie
# 1398      Saint-Georges-de-Noisné          Nouvelle-Aquitaine
# 676       Saint-Germain-en-Coglès                    Bretagne
# 547            Saint-Jean-d'Illac          Nouvelle-Aquitaine
# 1595            Saint-Jean-de-Luz          Nouvelle-Aquitaine
# 164                   Saint-Josse             Hauts-de-France
# 717                  Saint-Junien          Nouvelle-Aquitaine
# 1451     Saint-Just-Saint-Rambert        Auvergne-Rhône-Alpes
# 183       Saint-Laurent-d'Aigouze                   Occitanie
# 1153         Saint-Laurent-du-Var  Provence-Alpes-Côte d'Azur
# 987           Saint-Lon-les-Mines          Nouvelle-Aquitaine
# 1053                  Saint-Mandé               Île-de-France
# 1084         Saint-Martin-d'Hères        Auvergne-Rhône-Alpes
# 49       Saint-Martin-de-Seignanx          Nouvelle-Aquitaine
# 99        Saint-Martin-la-Garenne               Île-de-France
# 119         Saint-Maur-des-Fossés               Île-de-France
# 14      Saint-Maurice-de-Gourdans        Auvergne-Rhône-Alpes
# 440          Saint-Maurice-l'Exil        Auvergne-Rhône-Alpes
# 1028       Saint-Médard-en-Jalles          Nouvelle-Aquitaine
# 783                 Saint-Offenge        Auvergne-Rhône-Alpes
# 379      Saint-Orens-de-Gameville                   Occitanie
# 147     Saint-Paul-Trois-Châteaux        Auvergne-Rhône-Alpes
# 90             Saint-Paul-lès-Dax          Nouvelle-Aquitaine
# 702       Saint-Pierre-lès-Elbeuf                   Normandie
# 221                  Saint-Priest        Auvergne-Rhône-Alpes
# 367         Saint-Pée-sur-Nivelle          Nouvelle-Aquitaine
# 655                 Saint-Raphaël  Provence-Alpes-Côte d'Azur
# 774    Saint-Sulpice-le-Guérétois          Nouvelle-Aquitaine
# 42        Saint-Symphorien-d'Ozon        Auvergne-Rhône-Alpes
# 985     Saint-Sébastien-sur-Loire            Pays de la Loire
# 1076                  Saint-Usuge     Bourgogne-Franche-Comté
# 214       Saint-Vigor-d'Ymonville                   Normandie
# 298                   Saint-Épain         Centre-Val de Loire
# 345                 Saint-Étienne        Auvergne-Rhône-Alpes
# 413      Saint-Étienne-du-Rouvray                   Normandie
# 187    Saint-Étienne-du-Valdonnez                   Occitanie
# 118                  Sainte-Agnés        Auvergne-Rhône-Alpes
# 1073             Sainte-Anastasie                   Occitanie
# 561       Sainte-Flaive-des-Loups            Pays de la Loire
# 947      Sainte-Foy-Saint-Sulpice        Auvergne-Rhône-Alpes
# 563        Sainte-Gemme-la-Plaine            Pays de la Loire
# 245           Sainte-Marie-Kerque             Hauts-de-France
# 15                        Saintes          Nouvelle-Aquitaine
# 1476                    Sallebœuf          Nouvelle-Aquitaine
# 78              Salon-de-Provence  Provence-Alpes-Côte d'Azur
# 488             Salses-le-Château                   Occitanie
# 1623                    Sarcelles               Île-de-France
# 1209             Sarlat-la-Canéda          Nouvelle-Aquitaine
# 351           Saulx-les-Chartreux               Île-de-France
# 33            Segré-en-Anjou Bleu            Pays de la Loire
# 1616                    Sierville                   Normandie
# 891                  Sin-le-Noble             Hauts-de-France
# 1584                      Sorgues  Provence-Alpes-Côte d'Azur
# 1345                   Strasbourg                   Grand Est
# 949                Sucé-sur-Erdre            Pays de la Loire
# 38                       Suresnes               Île-de-France
# 739                     Sèvremont            Pays de la Loire
# 494                        Sèvres               Île-de-France
# 1033                     Sérignan                   Occitanie
# 591                         Taden                    Bretagne
# 548                       Talence          Nouvelle-Aquitaine
# 1231        Talmont-Saint-Hilaire            Pays de la Loire
# 1306                       Tarnos          Nouvelle-Aquitaine
# 684                       Taverny               Île-de-France
# 87                          Tendu         Centre-Val de Loire
# 1507                       Thiais               Île-de-France
# 414                    Thionville                   Grand Est
# 29               Thonon-les-Bains        Auvergne-Rhône-Alpes
# 282             Tignieu-Jameyzieu        Auvergne-Rhône-Alpes
# 1590                       Toulon  Provence-Alpes-Côte d'Azur
# 229                      Toulouse                   Occitanie
# 1675                    Tourcoing             Hauts-de-France
# 418                         Tours         Centre-Val de Loire
# 80           Treis-Sants-en-Ouche                   Normandie
# 341               Triel-sur-Seine               Île-de-France
# 1578               Trois-Rivières             Hauts-de-France
# 108                         Tulle          Nouvelle-Aquitaine
# 1478            Vaison-la-Romaine  Provence-Alpes-Côte d'Azur
# 775                   Val d'Oingt        Auvergne-Rhône-Alpes
# 766                  Valenciennes             Hauts-de-France
# 1244                    Vallauris  Provence-Alpes-Côte d'Azur
# 685                       Valréas  Provence-Alpes-Côte d'Azur
# 709                    Valserhône        Auvergne-Rhône-Alpes
# 501           Vandœuvre-lès-Nancy                   Grand Est
# 1589                       Vannes                    Bretagne
# 541                Vaulx-en-Velin        Auvergne-Rhône-Alpes
# 73                        Vauréal               Île-de-France
# 1279                Vaux-le-Pénil               Île-de-France
# 558                       Venette             Hauts-de-France
# 395                        Verdun                   Grand Est
# 954            Verdun-sur-Garonne                   Occitanie
# 908                        Vernon                   Normandie
# 438          Verrières-le-Buisson               Île-de-France
# 665                    Versailles               Île-de-France
# 30                         Vienne        Auvergne-Rhône-Alpes
# 1007                      Vierzon         Centre-Val de Loire
# 1409            Vigneux-sur-Seine               Île-de-France
# 400              Ville-sous-Anjou        Auvergne-Rhône-Alpes
# 683           Villebon-sur-Yvette               Île-de-France
# 576                    Villemaury         Centre-Val de Loire
# 1062            Villenave-d'Ornon          Nouvelle-Aquitaine
# 1081            Villeneuve-Loubet  Provence-Alpes-Côte d'Azur
# 1203     Villeneuve-Saint-Georges               Île-de-France
# 798        Villeneuve-lès-Avignon                   Occitanie
# 1402           Villeneuve-sur-Lot          Nouvelle-Aquitaine
# 442             Villers-Cotterêts             Hauts-de-France
# 317                  Villethierry     Bourgogne-Franche-Comté
# 531                  Villeurbanne        Auvergne-Rhône-Alpes
# 1365              Villiers-le-Bel               Île-de-France
# 742            Villiers-sur-Marne               Île-de-France
# 232                     Violaines             Hauts-de-France
# 1276               Viry-Châtillon               Île-de-France
# 560               Vitry-sur-Seine               Île-de-France
# 938                         Vitré                    Bretagne
# 901                Viuz-en-Sallaz        Auvergne-Rhône-Alpes
# 528           Vélizy-Villacoublay               Île-de-France
# 1548                       Vémars               Île-de-France
# 839                    Vénissieux        Auvergne-Rhône-Alpes
# 425               Vétraz-Monthoux        Auvergne-Rhône-Alpes
# 1496                       Wailly             Hauts-de-France
# 802                Warloy-Baillon             Hauts-de-France
# 1246                    Wattrelos             Hauts-de-France
# 1316                   Westhoffen                   Grand Est
# 1077                       Woippy                   Grand Est
# 463                        Yerres               Île-de-France
# 1387                   Yssingeaux        Auvergne-Rhône-Alpes
# 956                     Zoufftgen                   Grand Est
# 745                    Échirolles        Auvergne-Rhône-Alpes
# 781                       Écouves                   Normandie
# 182                     Élancourt               Île-de-France
# 344              Épieds-en-Beauce         Centre-Val de Loire
# 801                        Épinal                   Grand Est
# 972               Épinay-sur-Orge               Île-de-France
# 697              Épinay-sur-Seine               Île-de-France
# 411                        Éragny               Île-de-France
# 189                       Étampes               Île-de-France
# 115              Étoile-sur-Rhône        Auvergne-Rhône-Alpes
# 679            Évry-Courcouronnes               Île-de-France

# %%
# Compte le nombre de lignes intégralement dupliquées
print(f"Il y a {df.duplicated(keep=False).sum()} lignes intégralement dupliquées")

# Affiche les observations intégralement dupliquées
df[df.duplicated(keep=False)]
# Out:
# Il y a 0 lignes intégralement dupliquées
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, item_created_at, item_status, sale_price, cost, category, department, brand, product_name, order_status, order_created_at, shipped_at, delivered_at, user_id, gender, country, state, city]
# Index: []

# %%
#Vérifions qu'il n'y a pas de données négatives ou aberrrantes grace au min/max (en particulier pour cost & sale_price)
df.describe()
# Out:
#             order_id  order_item_id    product_id   sale_price         cost  \
# count    1679.000000    1679.000000   1679.000000  1679.000000  1679.000000
# mean    60851.683740   88372.698035   7922.506254    57.021769    27.460066
# std     35655.502994   51820.578196   4680.553838    69.682245    31.854450
# min       359.000000     517.000000     12.000000     1.820000     0.749840
# 25%     30357.000000   44069.500000   3812.000000    19.990000     9.681000
# 50%     60827.000000   88353.000000   7907.000000    38.000000    18.230800
# 75%     90911.000000  132106.000000  12053.000000    68.000000    33.232345
# max    124791.000000  181230.000000  15982.000000   903.000000   437.052001
#
#             user_id
# count   1679.000000
# mean   48702.836212
# std    28441.847629
# min      279.000000
# 25%    24349.000000
# 50%    48715.000000
# 75%    72541.000000
# max    99717.000000

# %%
# Verifions qu'il n'y a pas d'incohérence entre les product_id et les category (un product_id ne doit être affecté qu'à une seule category)
category_counts = df.groupby('product_id')['category'].nunique() #  compter le nombre de catégories uniques par product_id
product_ids_multiple_categories = category_counts[category_counts > 1].index # sélectionner les product_id avec plus d'une catégorie

df_pb_cat_pdct = df[df['product_id'].isin(product_ids_multiple_categories)]  
print(df_pb_cat_pdct) # si vide affiché -> pas de pb
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, item_created_at, item_status, sale_price, cost, category, department, brand, product_name, order_status, order_created_at, shipped_at, delivered_at, user_id, gender, country, state, city]
# Index: []

# %%
# Verifions qu'il n'y a pas d'incohérence entre les product_id et les prix de vente (un product_id ne doit être affecté qu'à une seul sale_price)
price_counts = df.groupby('product_id')['sale_price'].nunique() #  compter le nombre de prix uniques par product_id
product_ids_multiple_prices =price_counts[price_counts > 1].index # sélectionner les product_id avec plus d'un sale_price

df_pb_price_pdct = df[df['product_id'].isin(product_ids_multiple_prices)] 
print(df_pb_price_pdct) # si vide -> pas de pb
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, item_created_at, item_status, sale_price, cost, category, department, brand, product_name, order_status, order_created_at, shipped_at, delivered_at, user_id, gender, country, state, city]
# Index: []

# %%
# Verifions qu'il n'y a pas d'incohérence entre les product_id et les couts (un product_id ne doit être affecté qu'à une seul cost)
cost_counts = df.groupby('product_id')['cost'].nunique() #  compter le nombre de prix uniques par product_id
product_ids_multiple_cost =cost_counts[cost_counts > 1].index # sélectionner les product_id avec plus d'un cost

df_pb_cost_pdct = df[df['product_id'].isin(product_ids_multiple_cost)] 
print(df_pb_cost_pdct) # si vide -> pas de pb
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, item_created_at, item_status, sale_price, cost, category, department, brand, product_name, order_status, order_created_at, shipped_at, delivered_at, user_id, gender, country, state, city]
# Index: []

# %%
# Création d'un mini dictionnaire de données : définition, type, exemple):


definitions = {
    "order_id": "référence (ID) de la commande",
    "order_item_id": "référence (ID) de l'article inclus dans la commande",
    "product_id": "référence de l'article (au sens catalogue) - sans lien avec la commande",
    "item_created_at": "date de création de l'article ",
    "item_status": "statut de l'article commmandé",
    "sale_price": "prix de vente de l'article",
    "cost": "coût de l'article",
    "category": "catégorie de l'article",
    "department": "département de l'article / de sa catégorie",
    "brand": "marque de l'article",
    "product_name":"nom de l'article",
    "order_status": "statut de la commande",
    "order_created_at":"date de création de la commande",
    "shipped_at": "date d'expédition",
    "delivered_at": "date de livraison",
    "user_id":"identifiant du client",
    "gender":"genre du client",
    "country": "pays de la livraison",
    "state":"région de la livraison",
    "city":"ville de la livraion"
}

mini_dict = []
for col in df.columns:
    col_info = {
        "colonne": col,
        "definition": definitions.get(col, "Définition à compléter"),
        "type": str(df[col].dtype),
        "exemple": df[col].dropna().iloc[0]
    }
    mini_dict.append(col_info)
mini_dict
# Out:
# [{'colonne': 'order_id',
#   'definition': 'référence (ID) de la commande',
#   'type': 'int64',
#   'exemple': np.int64(19425)},
#  {'colonne': 'order_item_id',
#   'definition': "référence (ID) de l'article inclus dans la commande",
#   'type': 'int64',
#   'exemple': np.int64(28112)},
#  {'colonne': 'product_id',
#   'definition': "référence de l'article (au sens catalogue) - sans lien avec la commande",
#   'type': 'int64',
#   'exemple': np.int64(6983)},
#  {'colonne': 'item_created_at',
#   'definition': "date de création de l'article ",
#   'type': 'object',
#   'exemple': '2023-01-01 06:18:03+00:00'},
#  {'colonne': 'item_status',
#   'definition': "statut de l'article commmandé",
#   'type': 'object',
#   'exemple': 'Shipped'},
#  {'colonne': 'sale_price',
#   'definition': "prix de vente de l'article",
#   'type': 'float64',
#   'exemple': np.float64(29.5)},
#  {'colonne': 'cost',
#   'definition': "coût de l'article",
#   'type': 'float64',
#   'exemple': np.float64(16.047999992966652)},
#  {'colonne': 'category',
#   'definition': "catégorie de l'article",
#   'type': 'object',
#   'exemple': 'Shorts'},
#  {'colonne': 'department',
#   'definition': "département de l'article / de sa catégorie",
#   'type': 'object',
#   'exemple': 'Women'},
#  {'colonne': 'brand',
#   'definition': "marque de l'article",
#   'type': 'object',
#   'exemple': 'Fox'},
#  {'colonne': 'product_name',
#   'definition': "nom de l'article",
#   'type': 'object',
#   'exemple': 'Fox Juniors Momentum Short'},
#  {'colonne': 'order_status',
#   'definition': 'statut de la commande',
#   'type': 'object',
#   'exemple': 'Shipped'},
#  {'colonne': 'order_created_at',
#   'definition': 'date de création de la commande',
#   'type': 'object',
#   'exemple': '2022-12-29 10:00:00+00:00'},
#  {'colonne': 'shipped_at',
#   'definition': "date d'expédition",
#   'type': 'object',
#   'exemple': '2022-12-30 11:29:00+00:00'},
#  {'colonne': 'delivered_at',
#   'definition': 'date de livraison',
#   'type': 'object',
#   'exemple': '2023-01-04 03:03:00+00:00'},
#  {'colonne': 'user_id',
#   'definition': 'identifiant du client',
#   'type': 'int64',
#   'exemple': np.int64(15644)},
#  {'colonne': 'gender',
#   'definition': 'genre du client',
#   'type': 'object',
#   'exemple': 'F'},
#  {'colonne': 'country',
#   'definition': 'pays de la livraison',
#   'type': 'object',
#   'exemple': 'France'},
#  {'colonne': 'state',
#   'definition': 'région de la livraison',
#   'type': 'object',
#   'exemple': 'Centre-Val de Loire'},
#  {'colonne': 'city',
#   'definition': 'ville de la livraion',
#   'type': 'object',
#   'exemple': 'Corquilleroy'}]

# %% [markdown]
# ## Analyse et identification des prochaines étapes à mettre en place :
# ### Pas de lignes dupliquées -> pas d'action
# ### 1. La colonnes Brand a deux valeurs manquantes. Nous allons les remplacer.
# ### 2. Format des objets : les données item_created_at, order_created_at, shipped_at, delivered_at devraient être des dates. Nous allons les convertir.
# ### 3. Les colonnes shipped_at et delivered_at ont des valeurs manquantes. Nous allons vérifier si c'est normal ou non.
# ### 4. Nous vérifierons si les bornes temporelles sont cohérentes

# %% [markdown]
# ### 1. TRAITEMENT DES VALEURS MANQUANTES DANS BRAND

# %%
lignes_null_brand = df[df['brand'].isna()]
df_check = df[df['product_id'].isin(lignes_null_brand)]
# si le DataFrame est vide -> pas de correspondance avec d'autres lignes (product_id isolé), sinon on affiche les valeurs
if df_check[['product_id', 'brand']].empty:
    print("Pas de correspondance avec d'autres lignes (product_id isolée).")
else:
    print(df_check[['product_id', 'brand']])

pd.set_option('display.max_colwidth', None) # permet d'afficher toute la colonne (code ci-dessous) sans troncature
print(lignes_null_brand["product_name"]) # affiche les product name des lignes avec brand null
print(sorted(df["brand"].dropna().unique()))# on regarde toutes les brands existantes pour voir si on trouve qqch de cohérent / on classe par ordre alphabétique pour plus de lisibilité

#En comparant les product_name & brand_name, on reconnaît une valeur que l'on peut remplacer ('Out Of Print'). On va remplacer la valeur manquanate dans le dataframe")
df.loc[df['product_name'].str.contains('Out Of Print', na=False) & df['brand'].isna(), 'brand'] = 'Out Of Print'
# Out:
# Pas de correspondance avec d'autres lignes (product_id isolée).
# 320     The Very Hungry Caterpillar Classic Book Women's Slim Fit T-shirt by Out Of Print Clothing
# 1237                                                                 Husky Animal Hat with Mittens
# Name: product_name, dtype: object
# ['!it Jeans', "'47 Brand", '180s', '2XU', '2b by bebe', '5 Seasons', '525 America', '7 For All Mankind', 'A Pea in the Pod', 'A. Byer', 'A:X Armani Exchange', 'ADAR UNIFORMS', 'AG Adriano Goldschmied', 'AGB', 'AJs', 'AN1225', 'ASICS', 'Active Products', 'Activewear Apparel', 'Adriana', 'Adrianna Papell', 'Aegean', 'Affinitas Intimates', 'Alan Sloane', 'Alexander Del Rossa', 'Alfred Dunner', 'Alice & Trixie', "Alki'i", 'Allegra K', 'Allen Allen', 'Alternative', 'AmeriBag', 'American Apparel', 'Ames', 'Amnesty International', 'Anemone', 'Angelina', 'Angelina Hosiery', 'AnimalShirtsUSA', 'Anita', 'Anna-Kaci', 'Anne Klein', 'Anvil', 'Apt 9', 'Aqua', "Arc'teryx", 'Arianne', 'Artex', 'Artwedding', 'Assets', 'Athena', 'Atlas', 'Avenue', 'AxParis', 'BB Dakota', 'BCBGMAXAZRIA', 'BCBGeneration', 'BGSD', 'BIG STAR', 'BOOB-EEZ', 'Baby Be Mine', 'Bailey 44', 'Bali', 'Barely There', 'Beach Joy', 'Beauty Night', 'Becca by Rebecca Virtue', 'BedHead', 'Bella', 'Bella Materna', 'BellaBand', 'Belly Bandit', 'Bench', 'Berek', 'Berkshire', 'Besame', 'Betsey Johnson', 'Betty Boop', 'Beyond Yoga', 'Bianca NygÃ¥rd', 'Billabong', 'Blarney Woollen Mills', "Bloom's Outlet", "Bloomingdale's", 'Blue Juice', 'Blue Star Inc.', 'Body Glove', 'Body Language Fashions', 'Body Wrappers', 'Boxercraft', 'Bravado! Designs', 'Brave Soul', 'Braza', 'BridalPetticoat', 'Briggs', 'Bristols 6', 'Bslingerie', 'Bullhead', 'Bump', 'Burton', 'CARRAIG DONN KNITWEAR', 'CCV Inc', 'CEP', 'CW-X', 'Cactus Fashion', 'Calvin Klein', 'Calvin Klein Jeans', 'Calvin Klein Performance', 'Canada Goose', 'Capelli New York', 'Capezio', 'Carhartt', 'Caribbean Joe', 'Carnival', 'Carol Wright Gifts', 'Carole Hochman', 'Carraig Donn', 'Cashmere Int', 'Casual Moments', 'Casual Socks', 'Champion', 'Chaos', 'Charles River Apparel', 'Charter Club', 'Chaus', 'Chestnut Hill', 'Chicastic', 'Christopher Kelenc', 'Cinderella', 'Cinema Etoile', 'Claeson', 'Cleo', 'Cloris Murphy', 'Coal', 'Cole Haan', 'Collection XIIX', 'Columbia', 'Comfort Choice', 'Commando', 'Coolibar', 'Coquette', 'Coral Bay', 'CoreyLynnCalter', 'Corset Story', 'Corset-story', 'CorsetDeal', 'Cosabella', 'Cover Me', 'Craft', 'Croakies', 'Cuddl Duds', 'Cuffu Online', 'Curve Appeal', 'D&G Dolce & Gabbana', 'D.E.P.T.', 'DB Life Dana Buchman', 'DC', 'DG Eyewear', 'DKNYC', 'DL1961', 'DREAMS', 'DV by Dolce Vita', 'Dance 4 Less', 'Danny & Nicole', 'Danskin', 'Dapper World', 'Darn Tough', 'David Kahn', "David's Bridal", 'Dearfoams', 'Democracy', 'Design History', 'Devon & Jones', 'Dickies', 'Dickies Girl', 'Diesel', 'Disney', 'District Made', 'District Threads', 'Dockers', 'Dolce & Gabbana', 'Dr. Rey Shapewear', 'Drawstrings', 'DreamSacks', 'Duofold', 'ECHO', 'Ear Mitts; EarMitts', 'East Essence', 'Eberjey', 'Ecko Red', 'Ed Garments', 'Ed Hardy', 'Eddie Bauer', 'Edwards', 'Eileen West', 'Elan', 'Electric', 'Eliza J', 'Elomi', 'Emerson Street', 'Escargot Sportswear', 'Everjune', 'Everly Grey', 'ExOfficio', 'Expressiva Nursingwear', 'FINESSE', 'FOURSQUARE', 'FactoryExtreme', 'Famous Stars and Straps', 'Farr West', 'Fashion Essentials', 'Fashion Victim', 'Felina', 'Fennco', 'FineBrandShop', 'Fitness Etc.', 'Flexees', 'Fluff', 'Flying Monkey Jeans', 'Folter', 'Foot Traffic', 'Fox', 'Fox River Socks', 'FoxRiver', 'Frankie B.', "Frederick's of Hollywood", 'French Connection', 'FreshGear AFX', 'Freya', 'Fruit of the Loom', 'Full Tilt', 'Funfash', 'FursNewYork', 'G & S', 'G by GUESS', 'G-Star', 'GUESS', 'GUESS by Marciano', 'Gabby Skye', 'Game Gear', 'German Wear', 'Gildan', 'Gilden Tree', 'Gipsy Hosiery', 'Girls4Sport', 'Glamorise', 'Glamourmom', 'Goddess', 'Gold Toe', 'Gottex', 'Gracya', 'Grane', 'Greatlookz', 'Guide Gear', 'Gypsy 05', 'H2W', 'HKNB Heidi Klum for New Balance', 'HOBO', 'HOT', 'HOTmilk', 'HUE', 'HYP', 'Hanes', 'Hanky Panky', 'Hannah', 'Hanro', 'Harajuku', 'Hard Tail', 'Harley-Davidson', 'Harriton', 'Harry Potter', 'Hatley', 'Hello Kitty', 'Hermanny by ViX', 'Hey Viv !', 'High Style', 'Hip', 'Hold-Up Suspender Co.', 'Horny Toad', 'Hot  ...

# %%
# Pour l'autre ligne avec brand N/A, on remplace par "missing"

df['brand'] = df['brand'].fillna('Missing') 

df.isna().sum() # on vérifie qu'on n'a plus de valeurs manquantes pour brand
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# item_created_at        0
# item_status            0
# sale_price             0
# cost                   0
# category               0
# department             0
# brand                  0
# product_name           0
# order_status           0
# order_created_at       0
# shipped_at           546
# delivered_at        1043
# user_id                0
# gender                 0
# country                0
# state                  0
# city                   0
# dtype: int64

# %% [markdown]
# ### 2.CONVERSION DES DATES AU BON FORMAT : "item_created_at', "order_created_at", "shipped_at", "delivered_at"

# %%
# on se remet sur la racine du projet pour pouvoir aller chercher la fonction convert_dates définie dans le script
os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\chd78002\OneDrive - Groupe IPSEN\Documents\GIT-PROJECTS\Exam_Datagong_Doliveux

# %%
# on appelle la fonction convert_dates définie dans le script pour convertir les colonnes "item_created_at', "order_created_at", "shipped_at", "delivered_at" au format date
from src.utils import convert_dates


df = convert_dates(df)
df.head()
# Out:
#    order_id  order_item_id  product_id           item_created_at item_status  \
# 0     19425          28112        6983 2023-01-01 06:18:03+00:00     Shipped
# 1     19425          28113       10597 2023-01-01 06:44:58+00:00     Shipped
# 2      4710           6730       11792 2023-01-03 04:44:50+00:00    Complete
# 3     16618          24006         329 2023-01-03 15:13:39+00:00    Complete
# 4      4710           6731        5295 2023-01-05 06:43:09+00:00    Complete
#
#    sale_price       cost        category department                   brand  \
# 0   29.500000  16.048000          Shorts      Women                     Fox
# 1   20.000000  10.000000       Intimates      Women                  Wacoal
# 2   38.000000  18.468000       Intimates      Women        American Apparel
# 3   27.990000  16.402140     Tops & Tees      Women            Tri-Mountain
# 4   56.880001  29.577601  Pants & Capris      Women  Lauren by Ralph Lauren
#
#                                                  product_name order_status  \
# 0                                  Fox Juniors Momentum Short      Shipped
# 1                            Wacoal Women's B-Smooth Bralette      Shipped
# 2                       American Apparel Striped Chiffon Tank     Complete
# 3  Tri-Mountain Women's 3/4-Sleeve Pique Knit Polo Shirt. 601     Complete
# 4                            Lauren Ralph Lauren Velour Pants     Complete
#
#            order_created_at                shipped_at  \
# 0 2022-12-29 10:00:00+00:00 2022-12-30 11:29:00+00:00
# 1 2022-12-29 10:00:00+00:00 2022-12-30 11:29:00+00:00
# 2 2023-01-03 08:12:00+00:00 2023-01-03 09:14:00+00:00
# 3 2023-01-03 18:58:00+00:00 2023-01-05 13:23:00+00:00
# 4 2023-01-03 08:12:00+00:00 2023-01-03 09:14:00+00:00
#
#                delivered_at  user_id gender country                state  \
# 0                       NaT    15644      F  France  Centre-Val de Loire
# 1                       NaT    15644      F  France  Centre-Val de Loire
# 2 2023-01-04 03:03:00+00:00     3853      F  France        Île-de-France
# 3 2023-01-09 10:25:00+00:00    13422      F  France      Hauts-de-France
# 4 2023-01-04 03:03:00+00:00     3853      F  France        Île-de-France
#
#            city
# 0  Corquilleroy
# 1  Corquilleroy
# 2         Paris
# 3       Comines
# 4         Paris

# %%
print(f"Les valeurs de item_status sont {df["item_status"].unique()}")
print(f"Les valeurs de order_status sont {df["order_status"].unique()}")
# Out:
# Les valeurs de item_status sont ['Shipped' 'Complete' 'Processing' 'Returned' 'Cancelled']
# Les valeurs de order_status sont ['Shipped' 'Complete' 'Processing' 'Returned' 'Cancelled']

# %%
print(f"Les valeurs de category sont {df["category"].unique()}")
print(f"Les valeurs de state sont {df["state"].unique()}")
print(f"Les valeurs de brand sont {df["brand"].unique()}")
df.groupby('category')['brand'].unique().reset_index()
# Out:
# Les valeurs de category sont ['Shorts' 'Intimates' 'Tops & Tees' 'Pants & Capris' 'Blazers & Jackets'
#  'Dresses' 'Suits' 'Maternity' 'Jeans' 'Swim' 'Active'
#  'Jumpsuits & Rompers' 'Sleep & Lounge' 'Sweaters' 'Accessories'
#  'Fashion Hoodies & Sweatshirts' 'Plus' 'Socks & Hosiery' 'Leggings'
#  'Outerwear & Coats' 'Skirts' 'Clothing Sets']
# Les valeurs de state sont ['Centre-Val de Loire' 'Île-de-France' 'Hauts-de-France' 'Normandie'
#  'Occitanie' 'Nouvelle-Aquitaine' 'Auvergne-Rhône-Alpes'
#  'Pays de la Loire' "Provence-Alpes-Côte d'Azur" 'Bretagne'
#  'Bourgogne-Franche-Comté' 'Grand Est' 'Corse']
# Les valeurs de brand sont ['Fox' 'Wacoal' 'American Apparel' 'Tri-Mountain' 'Lauren by Ralph Lauren'
#  'Ulla Popken' 'Sutton Studio' 'Adrianna Papell' 'Jessica London'
#  'eloquii' 'Motherhood Maternity' 'Lee' 'ECHO' 'BB Dakota'
#  'Hot from Hollywood' 'SmartWool' 'Sam & Lavi' 'MANGO' 'Brave Soul'
#  'Seven7' 'Carhartt' 'Moontree' 'Rafaella' 'SZ' 'Allegra K'
#  'Calvin Klein Jeans' 'Morris Costumes' 'Ray-Ban' 'Speedo' "Levi's"
#  'FineBrandShop' 'Nittany Outlet' 'Fennco' 'Volcom' 'Barely There'
#  'VIVILLI' 'Ozone' 'Greatlookz' 'Samanthas Style Shoppe' 'LOTUSTRADERS'
#  'David Kahn' 'Velvet' 'Cinema Etoile' 'Alfred Dunner' 'Fox River Socks'
#  'Baby Be Mine' 'TIE-DYES' 'Merry Modes' '525 America'
#  'Twelfth Street by Cynthia Vincent' 'Hot Topic' 'Momo Maternity'
#  'Woman Within' '!it Jeans' 'Charles River Apparel' 'FoxRiver'
#  'Juicy Couture' 'Kensie' 'Spree' 'Tommy Hilfiger'
#  'Sealed with a Kiss Designs Plus Size' 'What Katie Did' 'Devon & Jones'
#  '7 For All Mankind' 'French Connection' 'BCBGMAXAZRIA' 'Rich & Skinny'
#  'Girls4Sport' 'Everjune' 'Champion' 'Wallflower' 'Dockers'
#  'Jessica Simpson' 'FactoryExtreme' 'D&G Dolce & Gabbana' '2b by bebe'
#  'Tahari' 'Bslingerie' 'Cactus Fashion' 'Hanes' 'BCBGeneration'
#  'BridalPetticoat' 'Woolrich' 'Pendleton' 'Pearl iZUMi' 'Jezebel'
#  'Nautica' 'Velrose' 'Anne Klein' 'Ultra Flirt' 'MW22' 'TapouT'
#  'Alternative' 'Oakley' 'Harley-Davidson' 'Roxy' 'Kiss' 'Rene Rofe'
#  'Sentiments' 'Olga' 'Up2date Fashion' 'Sunsets' 'HUE' 'Selena Gomez'
#  'AxParis' 'TrendsBlue' 'SEX NIGHT' 'Moving Comfort' 'True Religion' 'AJs'
#  'Ice' 'Tokidoki' 'Berkshire' 'Maple Clothing' 'Patty' 'Sourpuss Clothing'
#  'Bali' 'Karen Nueburger' 'Spanx' 'Cuffu Online' 'Atlas' 'Next Level'
#  'Parker' 'Splendid' 'James Jeans' 'DG Eyewear' 'Assets' 'K. Bell'
#  'DREAMS' 'The North Face' 'Hurley' "Weber's Leather" 'Dearfoams'
#  'Miss Me' 'INDERA THERMALS' 'VIP BOUTIQUE' 'Three Dots' 'London Times'
#  'Hatley' 'Lucky Brand' 'ToeSox' 'Gottex' 'Suit Studio' 'Lysse'
#  'Lilo Maternity' 'Horny Toad' 'HOBO' 'Jolt' 'Calvin Klein' 'Spalding'
#  'Hanro' 'Vitamin A' 'Sunny Belt' 'Larry Levine' 'Elomi' 'Modern Heritage'
#  'Beach Joy' 'Rock Revival' 'Playtex' 'JAG' "Not Your Daughter's Jeans"
#  'Hudson' 'Ritchie Swimwear' 'Full Tilt' 'Blarney Woollen Mills' 'Bella'
#  'Claeson' 'Ibex' 'Democracy' 'CW-X' 'Scottevest' 'Betsey Johnson'
#  'Athena' 'Ed Hardy' 'Chicastic' 'Carol Wright Gifts' 'ASICS'
#  'eVogues Apparel' 'Fashion Victim' 'Anna-Kaci' 'prAna' 'Lilly Pulitzer'
#  'MICHAEL Michael Kors' 'V Fraas' "Arc'teryx" 'LibbySue' 'AGB' 'Kasper'
#  'Magic Suit' 'Jones New York' 'Disney' 'Columbia' 'HYP' 'D.E.P.T.'
#  'Flexees' 'Expressiva Nursingwear' 'Roma Costume' 'PAIGE' 'TYR'
#  'Icebreaker' 'Mommy Paradise' 'Chaus' 'GUESS by Marciano' 'alo Sport'
#  'Harajuku' 'Style & Co.' 'Fruit of the Loom' 'Paul Frank' 'GUESS'
#  'Coolibar' 'Game Gear' 'Southpole' "L'eggs" 'Private Island' 'SportHill'
#  'Coquette' 'Joie' 'Shoshanna' 'Corset-story' 'Via Spiga' 'Miss Elaine'
#  'Cashmere Int' 'Corset Story' 'Out Of Print' 'Eddie Bauer' "Alki'i"
#  'KUT from the Kloth' 'Maidenform' 'Belly Bandit' 'Jules & Jim'
#  'Soho Girls' 'Dickies' 'ililily' 'Wigwam' 'Ripe Maternity' 'TVTimeDirect'
#  'Karen Kane' "Warner's" 'Foot Traffic' 'Lily of France' 'Charter Club'
#  'Robin Piccone' 'Alexander Del Rossa' 'Yala' 'Mountain Hardwear'
#  'Croakies' 'Design History' 'iCollection Lingerie' 'Briggs'
#  'Rompers and Jumpsuits HS' 'Sag Harbor' 'Levusha Fashions' 'Glamourmom'
#  'Intimates Boutique' 'Leading Lady' 'BedHead' 'Yelete' 'Styles For Less'
#  'Escargot Sportswear' 'Hannah' 'Royal Robbins' 'Sweatsedo'
#  'Only Necessities' 'G & S' 'Guide Gear' 'ian Leino Design' 'Vanity Fair'
#  'House Brand' 'Jessica Howard' 'La Leche League' 'Bailey 44'
#  'Capelli New York' 'Huafeng' 'FreshGear AFX' 'Texcyngoods' 'Second Base'
#  'Lindy Bop' 'Pashminas4u' '2XU' 'Christopher Kelenc' 'Impact Fitness'
#  'Braza' 'Symphony Designs' 'Sheridyn Swim' 'Melinda G' 'Edwards'
#  'Eberjey' 'Active Products' 'JiMarti' 'National' 'Hanky Panky'
#  'Ed Garments' 'Laura' 'Rampage' 'Avenue' 'G by GUESS' 'Alice & Trixie'
#  'Bench' 'Hard Tail' 'Cleo' 'Cosabella' 'WeekenderÂ®' 'Capezio'
#  'Tea Collection' 'Canada Goose' 'High Style' 'Steve Madden' 'Betty Boop'
#  'Medela' 'Rebecca Taylor' 'Miraclesuit' 'Underworks' 'Maui Jim' 'Merrell'
#  'NoeMie' 'DC' 'Rumina Nursingwear' 'Calvin Klein Performance'
#  'Shaper Corset' 'Bianca NygÃ¥rd' 'CEP' 'Lipo in a Box' 'Cuddl Duds'
#  'Hello Kitty' 'Red Engine' 'Vx Intimate Inc' 'Reebok' 'Panache' 'Anemone'
#  'MG' 'Kenneth Cole' 'Commando' 'Wool Overs' 'Cloris Murphy' 'VA VA VOOM'
#  'Fashion Essentials' 'Tresics' 'boxed-gifts' 'US Fairytailes'
#  'Beyond Yoga' 'Silver Jeans' 'Nike' 'Nollia' 'Lilyette' 'AnimalShirtsUSA'
#  'Darn Tough' 'Sexy You Can Do' 'Eliza J' 'White Orchid' 'Apt 9'
#  'Artwedding' 'FOURSQUARE' 'Blue Juice' 'Va Bien' "Bloom's Outlet"
#  'Rasta/NYE' 'TD' 'Shadowline' 'Hey Viv !' 'Lamaze' 'Bravado! Designs'
#  'Paddi Murphy' 'ADAR UNIFORMS' 'Carnival' 'Tripp NYC' 'Body Glove'
#  'Outdoor Research' 'Fitness Etc.' 'Moonar' 'L*Space' 'Anita'
#  'Activewear Apparel' 'Aqua' 'La Fiorentina' '180s' 'Michael Kors'
#  'The Trendy Me' 'Jockey' 'Sock It To Me' "b.tempt'd by Wacoal"
#  'Stella Elyse' 'DB Life Dana Buchman' 'Pencey' 'ExOfficio' 'Rocawear'
#  'Trina Turk' 'Flying Monkey Jeans' 'A:X Armani Exchange' 'Ted Baker'
#  'Artex' 'Ecko Red' 'Torrid' 'Burton' 'La Leche League International'
#  'Wonderbra' 'Goddess' '[BLANKNYC]' 'Under Moments' 'Natori' 'Lorpen'
#  'Amnesty International' 'Scarf_tradinginc' 'Minus33 Merino Wool'
#  'Palmetto Fundraising' 'Tops and Bottoms HS' 'Casual Moments'
#  'Only Hearts' 'Snoozies' 'Just Sexy' 'TAXI Wallet' 'Jeanstar' 'dollhouse'
#  'Kirra' 'Siwy' 'DKNYC' 'LeggingsQueen' 'German Wear' 'Miss Sixty'
#  'HOTmilk' 'A Pea in the Pod' 'Tiger Milly' 'ShaToBu' "O'Neill" 'Danskin'
#  'Electric' 'Cinderella' 'Star Vixen' 'Marina West' 'Body Wrappers'
#  'Soxnet' 'La Blanca' 'Craft' 'Thorlo' 'A. Byer' 'Locs' 'adidas'
#  'MJ Soffe' 'Fluff' 'DreamSacks' "Bloomingdale's" 'Dickies Girl'
#  'AG Adriano Goldschmied' 'Allen Allen' 'QT' 'Xfy' 'Ames' 'Leon Levin'
#  'ULTRAFINO PANAMA HAT' 'Johnstons of Elgin' "Frederick's of Hollywood"
#  "'47 Brand" 'DL1961' "Joe's Jeans" 'CoreyLynnCalter' 'Glamorise'
#  "Kleinert's" 'Purpura Erizo' 'Folter' 'Adriana' 'Sanctuary'
#  'Angelina Hosiery' 'La Perla' 'Eileen West' 'Japanese Weekend'
#  'East Essence' 'LookbookStore' 'Ocean Avenue' 'Roamans' '5 Seasons'
#  "The Cat's Pajamas" 'Danny & Nicole' 'Chestnut Hill' 'Gilden Tree'
#  'Blue Star Inc.' 'Bella Materna' 'Billabong' 'Neon Buddha' 'Mikarose'
#  'Red Dot' 'Metal Mulisha' 'Star' 'Romeo & Juliet Couture'
#  'Famous Stars and Straps' 'Boxercraft' 'Ear Mitts; EarMitts'
#  'SK Hat shop' 'Casual Socks' 'Seafolly' 'Collection XIIX' 'Freya' 'H2W'
#  'McGinn' 'Chaos' 'Surfside' 'AN1225' 'NI9NE' 'My Little Pony' 'Coal'
#  'L.A. Idol Jeans' 'Beauty Night' 'G-Star' 'Rago' 'Pulse/Iceburg' 'BGSD'
#  'Pink Lotus' 'SleepytimePjs' 'Outerwears' 'CCV Inc' 'FursNewYork' 'Sofie'
#  'Vedette' 'Farr West' 'Vince Camuto' 'Malco Modes' 'bebe' 'Luxury Divas'
#  'QSW' 'White Sierra' 'Orvis' 'Pony' 'Arianne' 'PLATINUM INTIMATES'
#  'Emerson Street' 'Ingrid & Isabel' 'Ilusion' 'Bump' 'Dance 4 Less'
#  'Drawstrings' 'Diesel' 'NEFF' 'Susan G. Komen for the CureÂ®'
#  'Van Heusen' 'Lauren Kiyomi' 'e.g. smith' 'Mermaid Maternity' 'Harriton'
#  'Quiksilver' 'Caribbean Joe' 'Comfort Choice' 'Sons Of Anarchy'
#  'Three Seasons Maternity' 'Gold Toe' 'HOT' 'Nicole Miller' 'Funfash'
#  'Berek' 'U.S. Polo Assn.' 'Pettipant' 'Missing' 'Lisse Leggings'
#  'NYGiftStop Knit Hat' "Vivian's Fashions" 'YogaColors' 'Nearly Me'
#  'Yoana Baraschi' 'Hip' 'Affinitas Intimates' 'AmeriBag' 'LIJA'
#  'WonderWink' 'Bullhead' 'Intimo' 'ThatsRad' 'Native Eyewear' 'Tiffany'
#  'Weatherproof' "David's Bridal" 'London Fog' 'Sox Shop' 'Frankie B.'
#  'Swim 365' 'FINESSE' 'Skyblue' 'Suncloud' 'Wildfox Couture'
#  'Oscar de la Renta' 'Angelina' 'Jolie' 'Life Is Good' 'District Made'
#  'Cover Me' 'Carole Hochman' 'Leo & Nicole' 'Wheel House Designs'
#  'Warm Things' 'Carraig Donn' 'Gabby Skye' 'Duofold' 'Knit Caps'
#  'Underglam' 'Royal Silk' 'Bristols 6' 'Alan Sloane' 'Dr. Rey Shapewear'
#  'Cole Haan' 'laundry by SHELLI SEGAL' 'Kiyonna' 'Becca by Rebecca Virtue'
#  'YMI' 'PJ Harlow' 'Gildan' 'NOM' 'CARRAIG DONN KNITWEAR'
#  'Robert Rodriguez' 'Dolce & Gabbana' 'Hold-Up Suspender Co.' 'Aegean'
#  'Sweetheart Slips' 'Tracy Reese' 'Kuhl' 'Skelapparel' 'Felina'
#  'BellaBand' 'JMS' 'Besame' 'CorsetDeal' 'The Natural' 'tabbisocks'
#  'BIG STAR' 'Turtle Fur' 'KOI Medical' 'Nantucket Brand' 'Gypsy 05'
#  'Gipsy Hosiery' 'Grane' 'Online-Welcome' 'Elan' 'Nvie Designs' 'Illusion'
#  'BOOB-EEZ' 'HKNB Heidi Klum for New Balance' 'DV by Dolce Vita'
#  'KAMALIKULTURE' 'Solutions That Stick' 'Womama' 'Ralph Lauren' 'Zoot'
#  'Anvil' 'NEVE' 'Coral Bay' 'Dapper World' 'Mary Green' 'Hermanny by ViX'
#  'Everly Grey' 'Terramar' 'Shupaca' 'Body Language Fashions'
#  'Sperry Top-Sider' 'Kate Spade' 'District Threads'
#  'The Pajamagram Company' 'Jantzen' 'Spiewak' 'Prego' 'Kavio'
#  'Harry Potter' 'Curve Appeal' 'Gracya']
#                          category  \
# 0                     Accessories
# 1                          Active
# 2               Blazers & Jackets
# 3                   Clothing Sets
# 4                         Dresses
# 5   Fashion Hoodies & Sweatshirts
# 6                       Intimates
# 7                           Jeans
# 8             Jumpsuits & Rompers
# 9                        Leggings
# 10                      Maternity
# 11              Outerwear & Coats
# 12                 Pants & Capris
# 13                           Plus
# 14                         Shorts
# 15                         Skirts
# 16                 Sleep & Lounge
# 17                Socks & Hosiery
# 18                          Suits
# 19                       Sweaters
# 20                           Swim
# 21                    Tops & Tees
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              brand
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [Ray-Ban, Greatlookz, Sealed with a Kiss Designs Plus Size, Cuffu Online, DG Eyewear, HOBO, Sunny Belt, Modern Heritage, TrendsBlue, LibbySue, Private Island, TVTimeDirect, Croakies, Carhartt, G & S, Pashminas4u, Christopher Kelenc, JiMarti, MG, Symphony Designs, Rasta/NYE, Outdoor Research, La Fiorentina, Artex, Scarf_tradinginc, Oakley, TAXI Wallet, Electric, Body Wrappers, Locs, SmartWool, Star, Ear Mitts; EarMitts, Coal, Collection XIIX, FursNewYork, boxed-gifts, Malco Modes, Luxury Divas, Dance 4 Less, HOT, Missing, NYGiftStop Knit Hat, AmeriBag, Native Eyewear, Tiffany, Suncloud, SK Hat shop, Dolce & Gabbana, H2W, tabbisocks, Allegra K, Activewear Apparel]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [SmartWool, Speedo, Fox River Socks, Tommy Hilfiger, Champion, Pearl iZUMi, Alternative, INDERA THERMALS, Spalding, CW-X, ASICS, prAna, Game Gear, SportHill, Alki'i, The North Face, FreshGear AFX, 2XU, Oakley, Capezio, Mountain Hardwear, CEP, Cuddl Duds, Columbia, Canada Goose, Beyond Yoga, Nike, ExOfficio, Minus33 Merino Wool, Samanthas Style Shoppe, Woman Within, Danskin, Active Products, Thorlo, adidas, Arc'teryx, MJ Soffe, Tri-Mountain, Pink Lotus, Pony, FOURSQUARE, Duofold, Hurley, Ibex]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [Ulla Popken, eloquii, Hot from Hollywood, Rafaella, Allegra K, Alfred Dunner, FactoryExtreme, 2b by bebe, Jones New York, AxParis, Sutton Studio, Pendleton, The Trendy Me, DB Life Dana Buchman, Pencey, Ted Baker, Tops and Bottoms HS, Anna-Kaci, A. Byer, Bloomingdale's, Trina Turk, 525 America, Lauren by Ralph Lauren, McGinn, Berek, Anne Klein, BB Dakota, DKNYC]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [Only Necessities, Orvis]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [Adrianna Papell, BB Dakota, Hot from Hollywood, Sam & Lavi, Velvet, French Connection, BCBGMAXAZRIA, Wallflower, MW22, American Apparel, AxParis, Allegra K, Parker, London Times, Calvin Klein, AGB, Anne Klein, Jessica Howard, Alki'i, Lindy Bop, 2b by bebe, Alice & Trixie, Rebecca Taylor, NoeMie, Jones New York, US Fairytailes, Eliza J, Hey Viv !, Moonar, eVogues Apparel, DKNYC, Miss Sixty, Tiger Milly, O'Neill, Cinderella, Star Vixen, Romeo & Juliet Couture, Design History, Jessica Simpson, Sofie, BCBGeneration, bebe, Samanthas Style Shoppe, Roxy, U.S. Polo Assn., Gabby Skye, laundry by SHELLI SEGAL, Kiyonna, Tracy Reese, Skelapparel, Robert Rodriguez, KAMALIKULTURE, dollhouse, Kavio, Curve Appeal]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [Nittany Outlet, FineBrandShop, Fox, Charles River Apparel, Juicy Couture, Cactus Fashion, TapouT, Roxy, True Religion, Tokidoki, Sourpuss Clothing, Volcom, Hurley, Claeson, Bella, Scottevest, Ed Hardy, Harajuku, ililily, Escargot Sportswear, Sweatsedo, Bench, DC, Allegra K, FOURSQUARE, TD, Activewear Apparel, Michael Kors, American Apparel, Next Level, Burton, Amnesty International, O'Neill, Splendid, MJ Soffe, Xfy, '47 Brand, Billabong, Metal Mulisha, Famous Stars and Straps, Boxercraft, Full Tilt, QSW, Orvis, Emerson Street, NEFF, Susan G. Komen for the CureÂ®, Paul Frank, Weatherproof, Wildfox Couture, Southpole, Life Is Good, District Made, Gildan, Jones New York, Allen Allen, DV by Dolce Vita, Ralph Lauren, District Threads]
# 6   [Wacoal, American Apparel, Allegra K, Morris Costumes, Barely There, VIVILLI, Merry Modes, Ulla Popken, Spree, What Katie Did, Everjune, Bslingerie, BridalPetticoat, Jezebel, Velrose, Kiss, Rene Rofe, Olga, Cinema Etoile, SEX NIGHT, Hanes, Spanx, Assets, Weber's Leather, FineBrandShop, Hanro, Elomi, Playtex, Bali, Ibex, Betsey Johnson, Chicastic, Arc'teryx, Anna-Kaci, Flexees, Roma Costume, Fruit of the Loom, Coquette, Corset-story, Corset Story, Maidenform, Warner's, Lily of France, iCollection Lingerie, Levusha Fashions, Intimates Boutique, Leading Lady, Vanity Fair, House Brand, Second Base, Braza, Eberjey, Hanky Panky, Laura, Cleo, Cosabella, Medela, Shaper Corset, Lipo in a Box, Vx Intimate Inc, Anemone, Commando, Fashion Essentials, Champion, Sexy You Can Do, Apt 9, Artwedding, Va Bien, Carnival, Fitness Etc., Anita, Jockey, b.tempt'd by Wacoal, Shadowline, Wonderbra, Goddess, Under Moments, Just Sexy, HOTmilk, ShaToBu, Calvin Klein, Rampage, Frederick's of Hollywood, Glamorise, Kleinert's, Adriana, Angelina Hosiery, La Perla, Beauty Night, Rago, Vedette, Farr West, Arianne, PLATINUM INTIMATES, Ilusion, Drawstrings, Comfort Choice, Pettipant, Lisse Leggings, Nearly Me, ...]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [Lee, Levi's, David Kahn, 7 For All Mankind, Rich & Skinny, Miss Me, Jolt, Rock Revival, Not Your Daughter's Jeans, Hudson, Democracy, PAIGE, Calvin Klein Jeans, KUT from the Kloth, HUE, Hot Topic, Volcom, Southpole, True Religion, Avenue, G by GUESS, Red Engine, Tripp NYC, Lucky Brand, Flying Monkey Jeans, Silver Jeans, L.A. Idol Jeans, G-Star, Diesel, Torrid, Joe's Jeans, Funfash, dollhouse, Eddie Bauer, Bullhead, Wallflower, GUESS]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [Brave Soul, Volcom, Twelfth Street by Cynthia Vincent, Kensie, AxParis, Allegra K, GUESS by Marciano, Rompers and Jumpsuits HS, VA VA VOOM, Rocawear, MANGO, FineBrandShop]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [Allegra K, Lysse, Bella, Anna-Kaci, Soho Girls, Foot Traffic, Yala, Yelete, Bailey 44, FineBrandShop, Hard Tail, Tea Collection, High Style, Bianca NygÃ¥rd, boxed-gifts, Nollia, Stella Elyse, Only Hearts, LeggingsQueen, ililily, Levi's, Folter, SK Hat shop, Torrid, CCV Inc, DC, Vivian's Fashions, Full Tilt, Angelina, JMS, Dapper World, Steve Madden]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [Motherhood Maternity, Hot from Hollywood, Baby Be Mine, Momo Maternity, Moving Comfort, Allegra K, Atlas, Lilo Maternity, Expressiva Nursingwear, Mommy Paradise, Patty, Belly Bandit, Jules & Jim, Ripe Maternity, Glamourmom, La Leche League, Impact Fitness, Melinda G, 7 For All Mankind, Underworks, Rumina Nursingwear, Panache, Lamaze, Bravado! Designs, La Leche League International, A Pea in the Pod, Leading Lady, ASICS, QT, Japanese Weekend, Bella Materna, Ingrid & Isabel, Bump, Lauren Kiyomi, Mermaid Maternity, Three Seasons Maternity, Anita, NOM, Hold-Up Suspender Co., BellaBand, FineBrandShop, Womama, Everly Grey, Prego]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [Devon & Jones, The North Face, Horny Toad, Larry Levine, MICHAEL Michael Kors, Allegra K, Columbia, Arc'teryx, Via Spiga, Anne Klein, Mountain Hardwear, Tommy Hilfiger, Guide Gear, Jessica Simpson, Levi's, Canada Goose, Calvin Klein, Calvin Klein Performance, Jones New York, Blue Juice, Trina Turk, Carol Wright Gifts, dollhouse, FineBrandShop, BGSD, Outerwears, White Sierra, Kirra, London Fog, Cole Haan, Kuhl, KOI Medical, HKNB Heidi Klum for New Balance, Nicole Miller, Spiewak]
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [Lauren by Ralph Lauren, Sutton Studio, MANGO, Carhartt, LOTUSTRADERS, Woman Within, Levi's, Dockers, Anne Klein, Samanthas Style Shoppe, Carol Wright Gifts, D.E.P.T., Southpole, Dickies, Jones New York, Karen Kane, Briggs, Styles For Less, Only Necessities, Nautica, Allegra K, Ed Garments, 2b by bebe, Lee, GUESS by Marciano, Not Your Daughter's Jeans, Calvin Klein, [BLANKNYC], German Wear, Ulla Popken, Jolt, Joe's Jeans, Dickies Girl, 5 Seasons, Red Dot, Capelli New York, Tripp NYC, Bailey 44, bebe, WonderWink, Eddie Bauer, FINESSE, Pendleton, Robert Rodriguez, KUT from the Kloth, Hard Tail, Grane, Ted Baker, Tops and Bottoms HS, Coral Bay, Volcom]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [Fennco, Oakley, TrendsBlue, Bali, DREAMS, Hanes, ToeSox, Spanx, Carhartt, Ray-Ban, V Fraas, Columbia, Bella, Olga, Assets, Texcyngoods, Symphony Designs, LibbySue, Lily of France, Maui Jim, SmartWool, Alki'i, Cashmere Int, Lilyette, 180s, Woman Within, Champion, Snoozies, Berkshire, Casual Moments, eVogues Apparel, ULTRAFINO PANAMA HAT, Johnstons of Elgin, Thorlo, Casual Socks, Collection XIIX, Fruit of the Loom, H2W, Chaos, TAXI Wallet, AN1225, Shadowline, Pulse/Iceburg, Gold Toe, Dickies, Sox Shop, Calvin Klein, boxed-gifts, Knit Caps, K. Bell, Turtle Fur, Online-Welcome, Swim 365, HUE, Sock It To Me, Kate Spade, Foot Traffic, Lee, Vanity Fair]
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [Fox, Sam & Lavi, !it Jeans, Ultra Flirt, Volcom, James Jeans, Calvin Klein Jeans, Lilly Pulitzer, Dockers, Style & Co., Joie, Carhartt, 2b by bebe, Hurley, Lucky Brand, 7 For All Mankind, PAIGE, Allegra K, WeekenderÂ®, Merrell, Silver Jeans, Flying Monkey Jeans, Woolrich, American Apparel, Southpole, Activewear Apparel, Jeanstar, Kirra, Siwy, Not Your Daughter's Jeans, Craft, Dickies Girl, AG Adriano Goldschmied, Ed Garments, DL1961, CoreyLynnCalter, Sanctuary, Roxy, Hot Topic, Splendid, Jolt, Quiksilver, LIJA, Levi's, Frankie B., YMI, Wallflower, Lee, BIG STAR, Nantucket Brand, Gypsy 05, KUT from the Kloth, Tripp NYC]
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [D&G Dolce & Gabbana, Pendleton, Hot Topic, Maple Clothing, VIP BOUTIQUE, Three Dots, Full Tilt, GUESS, Ice, FineBrandShop, ADAR UNIFORMS, Alki'i, Mountain Hardwear, Torrid, Hard Tail, Allegra K, Levi's, Purpura Erizo, East Essence, Rafaella, Anna-Kaci, Mikarose, Jones New York, Calvin Klein, Only Hearts, Tops and Bottoms HS, Samanthas Style Shoppe, Woman Within, Yoana Baraschi, Robert Rodriguez, MANGO, CoreyLynnCalter]
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [Moontree, Cinema Etoile, Nautica, Sentiments, Up2date Fashion, Karen Nueburger, Dearfoams, SmartWool, Hatley, Disney, Paul Frank, Miss Elaine, Charter Club, Alexander Del Rossa, BedHead, Capelli New York, Calvin Klein, Huafeng, National, Betty Boop, Hello Kitty, Betsey Johnson, Tommy Hilfiger, White Orchid, Shadowline, Paddi Murphy, HUE, Natori, Casual Moments, DreamSacks, Samanthas Style Shoppe, Eileen West, The Cat's Pajamas, Gilden Tree, Pendleton, SleepytimePjs, Juicy Couture, Rene Rofe, Hanes, Carol Wright Gifts, Hanro, Intimo, Oscar de la Renta, Carole Hochman, Warm Things, Royal Silk, DREAMS, Aegean, Activewear Apparel, Frederick's of Hollywood, PJ Harlow, Nvie Designs, Mary Green, Terramar, The Pajamagram Company]
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [Ozone, Hot Topic, FoxRiver, Jessica Simpson, Hanes, HUE, AJs, Berkshire, K. Bell, L'eggs, Cashmere Int, Wigwam, Betsey Johnson, Roxy, Ed Hardy, Rampage, Capelli New York, Anne Klein, Steve Madden, Darn Tough, Jones New York, Sock It To Me, Lorpen, Palmetto Fundraising, Foot Traffic, Soxnet, Ames, American Apparel, e.g. smith, dollhouse, ThatsRad, Angelina, Wheel House Designs, Alan Sloane, Capezio, Gipsy Hosiery, SmartWool, Carhartt, Zoot, Shupaca]
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [Jessica London, Tahari, Ice, Suit Studio, Kasper, Allegra K, Roamans, Danny & Nicole]
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [SZ, Calvin Klein Jeans, FineBrandShop, Samanthas Style Shoppe, 525 America, Tommy Hilfiger, Woolrich, Alternative, Patty, Blarney Woollen Mills, Carhartt, Fashion Victim, Chaus, Eddie Bauer, Devon & Jones, Design History, Sag Harbor, Lucky Brand, Edwards, BB Dakota, Kenneth Cole, Wool Overs, Sutton Studio, Aqua, eVogues Apparel, Allegra K, Splendid, High Style, Leon Levin, O'Neill, Anna-Kaci, Calvin Klein, LookbookStore, NI9NE, Alfred Dunner, Caribbean Joe, Pendleton, Joie, Jones New York, Sofie, Leo & Nicole, Carraig Donn, CARRAIG DONN KNITWEAR, Kensie, Elan, NEVE, bebe]
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [ECHO, Girls4Sport, Speedo, Sunsets, Gottex, Vitamin A, Beach Joy, JAG, Ritchie Swimwear, Athena, Magic Suit, TYR, Coolibar, Shoshanna, Robin Piccone, Hot from Hollywood, Roxy, Sheridyn Swim, Miraclesuit, Lucky Brand, Reebok, Cloris Murphy, Kenneth Cole, Bloom's Outlet, Body Glove, L*Space, Calvin Klein, Marina West, La Blanca, Ocean Avenue, Hurley, Trina Turk, Seafolly, Freya, Surfside, Nicole Miller, Woman Within, Swim 365, Cover Me, Becca by Rebecca Virtue, Hermanny by ViX, Sperry Top-Sider, Jantzen]
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                      [Tri-Mountain, Seven7, Allegra K, TIE-DYES, 2b by bebe, BCBGeneration, Harley-Davidson, Selena Gomez, Patty, Next Level, Splendid, Lucky Brand, eVogues Apparel, Jones New York, HYP, Icebreaker, alo Sport, Out Of Print, Carhartt, Hannah, Royal Robbins, ian Leino Design, Active Products, American Apparel, Tresics, AnimalShirtsUSA, Calvin Klein, Volcom, D.E.P.T., A:X Armani Exchange, Ecko Red, Bailey 44, Twelfth Street by Cynthia Vincent, Coolibar, Woman Within, Three Dots, Chaus, Fluff, Allen Allen, Devon & Jones, Chestnut Hill, Blue Star Inc., Neon Buddha, My Little Pony, G by GUESS, High Style, Hurley, Red Dot, Vince Camuto, Van Heusen, Harriton, Sons Of Anarchy, YogaColors, Roamans, PJ Harlow, Hey Viv !, Bella, Anvil, Harry Potter, Calvin Klein Jeans]

# %% [markdown]
# ### 3. TRAITEMENT DES N/A pour "shipped at" et "delivered at"
#
# #### Je vois dans la méthode info qu'il y a des valeurs manquantes pour "shipped at" et "delivered at".
# #### Les valeurs "shipped_at" et "delivered_at" doivent être cohérentes avec le "order_status"
# #### Je veux d'abord vérifier que les valeurs manquantes ne concernent que les commandes qui n'ont pas un statut "Complete"

# %%
#Vérification des valeurs de "order_status"
print(f"Les valeurs de order_status sont {df["order_status"].unique()}")
print("\n")
print("On peut estimer qu'on classe les statuts comme suit :",
"0. Cancelled → La commande a été annulée avant expédition.",
"1. Processing → La commande est en cours, rien n’a encore été expédié",
"2. Shipped → La commande a été expédiée, mais pas encore terminée",
"3. Complete → La commande a été livrée, tout est terminé",
"4. Returned → La commande a été renvoyée, donc elle est aussi terminée. On considère que la vente est annulée", sep="\n")
print("\n")

#Pour les NaT de "shipped at" et "delivered at", quel est le order_status associé?

#Filtrer les lignes où 'shipped_at' est NaT
NaT_shipped=df[df["shipped_at"].isna()]
# Afficher les valeurs de la colonne 'order_status' pour ces lignes
print(f"Les dates d'expéditions inexistantes (valeurs NaT de shipped_at) sont associées aux statuts de commandes suivants ('order_status'):{NaT_shipped['order_status'].unique()}")
print("\n")


#Filtrer les lignes où 'delivered_at' est NaT
NaT_delivered=df[df["delivered_at"].isna()]
# Afficher les valeurs de la colonne 'order_status' pour ces lignes
print(f"Les dates de livraison inexistantes (valeurs NaT de delivered_at) sont associées aux statuts de commandes suivants ('order_status'):{NaT_delivered['order_status'].unique()}")
print("\n")
print("Conclusion : Les valeurs manquantes sont cohérentes avec le statut de la commande associé.")
# Out:
# Les valeurs de order_status sont ['Shipped' 'Complete' 'Processing' 'Returned' 'Cancelled']
#
#
# On peut estimer qu'on classe les statuts comme suit :
# 0. Cancelled → La commande a été annulée avant expédition.
# 1. Processing → La commande est en cours, rien n’a encore été expédié
# 2. Shipped → La commande a été expédiée, mais pas encore terminée
# 3. Complete → La commande a été livrée, tout est terminé
# 4. Returned → La commande a été renvoyée, donc elle est aussi terminée. On considère que la vente est annulée
#
#
# Les dates d'expéditions inexistantes (valeurs NaT de shipped_at) sont associées aux statuts de commandes suivants ('order_status'):['Processing' 'Cancelled']
#
#
# Les dates de livraison inexistantes (valeurs NaT de delivered_at) sont associées aux statuts de commandes suivants ('order_status'):['Shipped' 'Processing' 'Cancelled']
#
#
# Conclusion : Les valeurs manquantes sont cohérentes avec le statut de la commande associé.

# %% [markdown]
# ### 4. VERIFIONS SI LES BORNES TEMPORELLES SONT COHERENTES

# %%
#Isolons les colonnes avec les dates :
date_cols= df[['item_created_at', 'order_created_at', 'shipped_at',"delivered_at"]]

#affichons le min/max pour chacune :
for col in date_cols:
    # dropna() enlève les NaT pour ce calcul
    min_date = df[col].dropna().min()
    max_date = df[col].dropna().max()
    
    print(f"Colonne '{col}':")
    print("  Min :", min_date)
    print("  Max :", max_date)
    print()

print("Les minimums sont toujours inférieurs aux maximums, et les dates restent réalistes (pas de dates futures ni très anciennes). De plus, les dates sont cohérentes entre statuts (exemple : maximum de  delivered at plus grand que tous els autres maximums)")
# Out:
# Colonne 'item_created_at':
#   Min : 2023-01-01 06:18:03+00:00
#   Max : 2024-12-31 10:40:48+00:00
#
# Colonne 'order_created_at':
#   Min : 2022-12-29 10:00:00+00:00
#   Max : 2024-12-31 05:13:00+00:00
#
# Colonne 'shipped_at':
#   Min : 2022-12-30 11:29:00+00:00
#   Max : 2025-01-02 02:26:00+00:00
#
# Colonne 'delivered_at':
#   Min : 2023-01-04 03:03:00+00:00
#   Max : 2025-01-02 13:06:00+00:00
#
# Les minimums sont toujours inférieurs aux maximums, et les dates restent réalistes (pas de dates futures ni très anciennes). De plus, les dates sont cohérentes entre statuts (exemple : maximum de  delivered at plus grand que tous els autres maximums)

# %%
# Verification de la cohérence des dates
pb_shipped=df[df["shipped_at"]<df["order_created_at"]]
print(pb_shipped)


pb_order_item=df[df["item_created_at"]<df["order_created_at"]]
print(pb_order_item[["item_created_at", "order_created_at"]].assign(
    item_created_at = pb_order_item["item_created_at"].dt.strftime('%Y-%m-%d'),
    order_created_at = pb_order_item["order_created_at"].dt.strftime('%Y-%m-%d')
))
# on a ajouté .dt.strftime pour un affichage plus lisible
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, item_created_at, item_status, sale_price, cost, category, department, brand, product_name, order_status, order_created_at, shipped_at, delivered_at, user_id, gender, country, state, city]
# Index: []
#      item_created_at order_created_at
# 2         2023-01-03       2023-01-03
# 3         2023-01-03       2023-01-03
# 5         2023-01-06       2023-01-06
# 6         2023-01-08       2023-01-08
# 7         2023-01-13       2023-01-13
# 9         2023-01-13       2023-01-13
# 10        2023-01-14       2023-01-14
# 12        2023-01-15       2023-01-15
# 14        2023-01-15       2023-01-15
# 18        2023-01-17       2023-01-17
# 20        2023-01-17       2023-01-17
# 24        2023-01-18       2023-01-18
# 25        2023-01-18       2023-01-18
# 26        2023-01-19       2023-01-19
# 27        2023-01-21       2023-01-21
# 28        2023-01-22       2023-01-22
# 29        2023-01-22       2023-01-22
# 31        2023-01-24       2023-01-24
# 37        2023-01-25       2023-01-26
# 38        2023-01-27       2023-01-27
# 40        2023-01-28       2023-01-28
# 41        2023-01-28       2023-01-28
# 43        2023-01-29       2023-01-29
# 46        2023-01-30       2023-01-30
# 48        2023-01-31       2023-01-31
# 51        2023-02-01       2023-02-01
# 52        2023-02-02       2023-02-02
# 54        2023-02-02       2023-02-02
# 56        2023-02-03       2023-02-03
# 62        2023-02-09       2023-02-09
# 67        2023-02-12       2023-02-12
# 70        2023-02-13       2023-02-13
# 72        2023-02-14       2023-02-14
# 79        2023-02-19       2023-02-19
# 80        2023-02-20       2023-02-20
# 81        2023-02-20       2023-02-20
# 82        2023-02-20       2023-02-20
# 84        2023-02-21       2023-02-21
# 87        2023-02-23       2023-02-23
# 88        2023-02-23       2023-02-23
# 91        2023-02-26       2023-02-26
# 93        2023-02-27       2023-02-27
# 95        2023-02-27       2023-02-27
# 99        2023-03-04       2023-03-04
# 100       2023-03-04       2023-03-04
# 101       2023-03-05       2023-03-05
# 104       2023-03-05       2023-03-05
# 106       2023-03-06       2023-03-06
# 107       2023-03-07       2023-03-07
# 110       2023-03-09       2023-03-09
# 111       2023-03-10       2023-03-10
# 112       2023-03-12       2023-03-12
# 113       2023-03-12       2023-03-12
# 114       2023-03-13       2023-03-13
# 115       2023-03-14       2023-03-15
# 116       2023-03-17       2023-03-17
# 118       2023-03-21       2023-03-21
# 121       2023-03-22       2023-03-22
# 126       2023-03-24       2023-03-24
# 127       2023-03-24       2023-03-24
# 129       2023-03-25       2023-03-25
# 133       2023-03-26       2023-03-26
# 136       2023-03-26       2023-03-26
# 137       2023-03-27       2023-03-27
# 143       2023-03-29       2023-03-29
# 144       2023-03-29       2023-03-29
# 147       2023-03-30       2023-03-31
# 148       2023-03-31       2023-03-31
# 151       2023-04-01       2023-04-01
# 152       2023-04-01       2023-04-02
# 154       2023-04-03       2023-04-03
# 155       2023-04-03       2023-04-03
# 156       2023-04-04       2023-04-04
# 158       2023-04-05       2023-04-05
# 159       2023-04-05       2023-04-05
# 163       2023-04-06       2023-04-07
# 164       2023-04-07       2023-04-07
# 166       2023-04-07       2023-04-07
# 168       2023-04-07       2023-04-07
# 169       2023-04-08       2023-04-08
# 170       2023-04-08       2023-04-08
# 173       2023-04-09       2023-04-09
# 175       2023-04-10       2023-04-10
# 179       2023-04-11       2023-04-11
# 182       2023-04-11       2023-04-11
# 184       2023-04-11       2023-04-11
# 187       2023-04-12       2023-04-13
# 189       2023-04-15       2023-04-15
# 191       2023-04-16       2023-04-16
# 192       2023-04-17       2023-04-17
# 193       2023-04-18       2023-04-18
# 194       2023-04-19       2023-04-19
# 195       2023-04-21       2023-04-21
# 197       2023-04-22       2023-04-22
# 198       2023-04-23       2023-04-23
# 199       2023-04-23       2023-04-23
# 201       2023-04-24       2023-04-24
# 203       2023-04-24       2023-04-24
# 204       2023-04-25       2023-04-25
# 209       2023-04-28       2023-04-28
# 211       2023-04-28       2023-04-28
# 212       2023-04-28       2023-04-28
# 214       2023-04-30       2023-04-30
# 215       2023-05-01       2023-05-01
# 222       2023-05-03       2023-05-03
# 225       2023-05-03       2023-05-03
# 227       2023-05-03       2023-05-04
# 229       2023-05-05       2023-05-05
# 231       2023-05-06       2023-05-06
# 232       2023-05-07       2023-05-07
# 233       2023-05-07       2023-05-07
# 234       2023-05-07       2023-05-07
# 235       2023-05-07       2023-05-08
# 237       2023-05-08       2023-05-08
# 240       2023-05-09       2023-05-09
# 244       2023-05-15       2023-05-15
# 245       2023-05-15       2023-05-15
# 246       2023-05-15       2023-05-15
# 247       2023-05-16       2023-05-16
# 248       2023-05-16       2023-05-17
# 249       2023-05-17       2023-05-17
# 250       2023-05-17       2023-05-17
# 252       2023-05-18       2023-05-18
# 253       2023-05-18       2023-05-18
# 254       2023-05-19       2023-05-19
# 255       2023-05-19       2023-05-19
# 256       2023-05-19       2023-05-20
# 257       2023-05-20       2023-05-20
# 258       2023-05-21       2023-05-21
# 259       2023-05-23       2023-05-23
# 260       2023-05-23       2023-05-23
# 261       2023-05-24       2023-05-24
# 262       2023-05-24       2023-05-24
# 263       2023-05-25       2023-05-25
# 266       2023-05-26       2023-05-26
# 267       2023-05-27       2023-05-27
# 268       2023-05-27       2023-05-28
# 270       2023-05-30       2023-05-30
# 271       2023-05-31       2023-05-31
# 272       2023-05-31       2023-06-01
# 273       2023-06-01       2023-06-01
# 275       2023-06-01       2023-06-01
# 276       2023-06-01       2023-06-01
# 277       2023-06-01       2023-06-01
# 278       2023-06-02       2023-06-02
# 279       2023-06-04       2023-06-04
# 280       2023-06-05       2023-06-05
# 286       2023-06-08       2023-06-08
# 287       2023-06-08       2023-06-08
# 293       2023-06-12       2023-06-12
# 294       2023-06-12       2023-06-12
# 295       2023-06-12       2023-06-12
# 296       2023-06-13       2023-06-13
# 299       2023-06-15       2023-06-15
# 304       2023-06-16       2023-06-16
# 308       2023-06-19       2023-06-19
# 309       2023-06-19       2023-06-19
# 310       2023-06-19       2023-06-19
# 312       2023-06-21       2023-06-21
# 315       2023-06-23       2023-06-23
# 317       2023-06-23       2023-06-23
# 319       2023-06-24       2023-06-24
# 320       2023-06-24       2023-06-24
# 323       2023-06-25       2023-06-25
# 325       2023-06-27       2023-06-27
# 327       2023-06-27       2023-06-27
# 329       2023-06-30       2023-06-30
# 331       2023-07-01       2023-07-01
# 339       2023-07-05       2023-07-05
# 340       2023-07-07       2023-07-07
# 341       2023-07-07       2023-07-07
# 342       2023-07-07       2023-07-07
# 344       2023-07-09       2023-07-09
# 345       2023-07-14       2023-07-14
# 346       2023-07-17       2023-07-17
# 347       2023-07-17       2023-07-18
# 348       2023-07-18       2023-07-18
# 349       2023-07-18       2023-07-18
# 351       2023-07-19       2023-07-20
# 353       2023-07-20       2023-07-20
# 354       2023-07-20       2023-07-20
# 355       2023-07-21       2023-07-21
# 356       2023-07-23       2023-07-23
# 358       2023-07-24       2023-07-24
# 360       2023-07-25       2023-07-25
# 363       2023-07-26       2023-07-26
# 364       2023-07-26       2023-07-26
# 367       2023-07-27       2023-07-27
# 368       2023-07-27       2023-07-27
# 369       2023-07-29       2023-07-29
# 370       2023-07-29       2023-07-29
# 373       2023-07-29       2023-07-30
# 374       2023-07-31       2023-07-31
# 375       2023-08-01       2023-08-01
# 377       2023-08-02       2023-08-02
# 378       2023-08-03       2023-08-03
# 379       2023-08-05       2023-08-05
# 383       2023-08-07       2023-08-07
# 387       2023-08-08       2023-08-08
# 388       2023-08-09       2023-08-09
# 389       2023-08-10       2023-08-10
# 391       2023-08-12       2023-08-12
# 392       2023-08-12       2023-08-12
# 393       2023-08-12       2023-08-12
# 394       2023-08-12       2023-08-12
# 395       2023-08-12       2023-08-13
# 396       2023-08-12       2023-08-13
# 403       2023-08-15       2023-08-15
# 404       2023-08-15       2023-08-15
# 406       2023-08-16       2023-08-16
# 409       2023-08-18       2023-08-18
# 413       2023-08-19       2023-08-19
# 418       2023-08-23       2023-08-23
# 423       2023-08-26       2023-08-26
# 424       2023-08-26       2023-08-26
# 425       2023-08-27       2023-08-27
# 427       2023-08-28       2023-08-28
# 428       2023-08-28       2023-08-28
# 429       2023-08-30       2023-08-30
# 430       2023-08-31       2023-08-31
# 431       2023-09-01       2023-09-01
# 438       2023-09-04       2023-09-04
# 440       2023-09-04       2023-09-04
# 442       2023-09-05       2023-09-05
# 448       2023-09-06       2023-09-06
# 449       2023-09-06       2023-09-06
# 450       2023-09-06       2023-09-06
# 451       2023-09-06       2023-09-07
# 452       2023-09-07       2023-09-07
# 454       2023-09-08       2023-09-09
# 455       2023-09-09       2023-09-09
# 457       2023-09-10       2023-09-10
# 460       2023-09-11       2023-09-11
# 462       2023-09-14       2023-09-14
# 463       2023-09-14       2023-09-14
# 467       2023-09-15       2023-09-16
# 468       2023-09-16       2023-09-16
# 469       2023-09-17       2023-09-17
# 471       2023-09-17       2023-09-17
# 476       2023-09-19       2023-09-19
# 477       2023-09-20       2023-09-20
# 478       2023-09-21       2023-09-21
# 479       2023-09-21       2023-09-21
# 480       2023-09-22       2023-09-23
# 483       2023-09-25       2023-09-25
# 484       2023-09-26       2023-09-26
# 485       2023-09-27       2023-09-27
# 486       2023-09-28       2023-09-28
# 487       2023-09-28       2023-09-28
# 488       2023-09-28       2023-09-28
# 490       2023-09-29       2023-09-29
# 491       2023-09-29       2023-09-29
# 494       2023-09-29       2023-09-30
# 497       2023-09-30       2023-09-30
# 498       2023-09-30       2023-09-30
# 499       2023-10-01       2023-10-01
# 501       2023-10-01       2023-10-01
# 503       2023-10-02       2023-10-02
# 504       2023-10-02       2023-10-02
# 508       2023-10-04       2023-10-04
# 510       2023-10-05       2023-10-05
# 511       2023-10-06       2023-10-06
# 512       2023-10-06       2023-10-06
# 513       2023-10-06       2023-10-06
# 515       2023-10-06       2023-10-06
# 516       2023-10-07       2023-10-07
# 521       2023-10-09       2023-10-09
# 522       2023-10-10       2023-10-10
# 528       2023-10-12       2023-10-12
# 529       2023-10-13       2023-10-13
# 530       2023-10-13       2023-10-13
# 531       2023-10-15       2023-10-15
# 535       2023-10-18       2023-10-18
# 538       2023-10-20       2023-10-20
# 539       2023-10-21       2023-10-21
# 540       2023-10-21       2023-10-21
# 541       2023-10-22       2023-10-22
# 542       2023-10-22       2023-10-22
# 543       2023-10-22       2023-10-22
# 545       2023-10-23       2023-10-23
# 547       2023-10-24       2023-10-24
# 548       2023-10-24       2023-10-24
# 549       2023-10-25       2023-10-25
# 551       2023-10-25       2023-10-25
# 553       2023-10-26       2023-10-26
# 554       2023-10-26       2023-10-26
# 558       2023-10-28       2023-10-29
# 559       2023-10-29       2023-10-29
# 560       2023-10-30       2023-10-30
# 561       2023-10-30       2023-10-30
# 562       2023-10-30       2023-10-31
# 563       2023-10-31       2023-10-31
# 568       2023-11-03       2023-11-03
# 570       2023-11-06       2023-11-07
# 572       2023-11-08       2023-11-08
# 573       2023-11-08       2023-11-08
# 576       2023-11-10       2023-11-10
# 578       2023-11-11       2023-11-11
# 579       2023-11-11       2023-11-11
# 580       2023-11-11       2023-11-11
# 581       2023-11-11       2023-11-11
# 582       2023-11-11       2023-11-11
# 583       2023-11-11       2023-11-12
# 586       2023-11-14       2023-11-14
# 587       2023-11-16       2023-11-16
# 588       2023-11-18       2023-11-18
# 589       2023-11-18       2023-11-18
# 592       2023-11-19       2023-11-19
# 594       2023-11-20       2023-11-20
# 601       2023-11-23       2023-11-23
# 603       2023-11-25       2023-11-25
# 604       2023-11-25       2023-11-26
# 608       2023-11-27       2023-11-27
# 609       2023-11-27       2023-11-28
# 611       2023-11-28       2023-11-28
# 612       2023-11-28       2023-11-28
# 613       2023-11-28       2023-11-28
# 614       2023-11-28       2023-11-28
# 619       2023-11-29       2023-11-29
# 620       2023-11-30       2023-11-30
# 623       2023-12-03       2023-12-03
# 627       2023-12-04       2023-12-04
# 628       2023-12-04       2023-12-04
# 630       2023-12-05       2023-12-05
# 634       2023-12-07       2023-12-07
# 635       2023-12-07       2023-12-07
# 637       2023-12-08       2023-12-08
# 639       2023-12-09       2023-12-10
# 640       2023-12-10       2023-12-10
# 641       2023-12-10       2023-12-11
# 642       2023-12-11       2023-12-11
# 643       2023-12-11       2023-12-11
# 644       2023-12-11       2023-12-11
# 645       2023-12-11       2023-12-12
# 647       2023-12-12       2023-12-12
# 650       2023-12-12       2023-12-12
# 651       2023-12-12       2023-12-12
# 653       2023-12-13       2023-12-13
# 654       2023-12-13       2023-12-13
# 655       2023-12-14       2023-12-14
# 658       2023-12-15       2023-12-15
# 661       2023-12-15       2023-12-16
# 664       2023-12-16       2023-12-16
# 665       2023-12-16       2023-12-16
# 667       2023-12-16       2023-12-17
# 670       2023-12-17       2023-12-17
# 671       2023-12-17       2023-12-17
# 673       2023-12-17       2023-12-18
# 676       2023-12-18       2023-12-19
# 679       2023-12-21       2023-12-21
# 680       2023-12-21       2023-12-21
# 681       2023-12-21       2023-12-21
# 682       2023-12-22       2023-12-22
# 683       2023-12-22       2023-12-22
# 684       2023-12-23       2023-12-23
# 685       2023-12-23       2023-12-23
# 686       2023-12-23       2023-12-23
# 689       2023-12-24       2023-12-24
# 691       2023-12-25       2023-12-25
# 692       2023-12-25       2023-12-25
# 693       2023-12-25       2023-12-25
# 694       2023-12-25       2023-12-25
# 695       2023-12-25       2023-12-25
# 697       2023-12-25       2023-12-26
# 698       2023-12-26       2023-12-26
# 699       2023-12-26       2023-12-26
# 702       2023-12-28       2023-12-28
# 704       2023-12-28       2023-12-28
# 706       2023-12-30       2023-12-30
# 707       2023-12-30       2023-12-30
# 709       2023-12-31       2023-12-31
# 710       2023-12-31       2023-12-31
# 711       2024-01-02       2024-01-02
# 712       2024-01-03       2024-01-03
# 713       2024-01-04       2024-01-04
# 714       2024-01-04       2024-01-04
# 715       2024-01-05       2024-01-05
# 716       2024-01-06       2024-01-06
# 717       2024-01-07       2024-01-07
# 718       2024-01-08       2024-01-08
# 719       2024-01-08       2024-01-08
# 720       2024-01-09       2024-01-09
# 721       2024-01-10       2024-01-10
# 722       2024-01-10       2024-01-10
# 723       2024-01-10       2024-01-10
# 727       2024-01-11       2024-01-11
# 729       2024-01-13       2024-01-13
# 730       2024-01-13       2024-01-13
# 733       2024-01-13       2024-01-14
# 734       2024-01-14       2024-01-14
# 735       2024-01-15       2024-01-16
# 736       2024-01-15       2024-01-16
# 737       2024-01-16       2024-01-16
# 738       2024-01-16       2024-01-16
# 740       2024-01-17       2024-01-17
# 744       2024-01-18       2024-01-18
# 745       2024-01-18       2024-01-18
# 748       2024-01-19       2024-01-19
# 752       2024-01-21       2024-01-21
# 753       2024-01-21       2024-01-21
# 754       2024-01-21       2024-01-21
# 755       2024-01-21       2024-01-21
# 757       2024-01-22       2024-01-22
# 758       2024-01-24       2024-01-24
# 759       2024-01-24       2024-01-24
# 760       2024-01-24       2024-01-24
# 761       2024-01-25       2024-01-25
# 763       2024-01-25       2024-01-25
# 764       2024-01-25       2024-01-25
# 765       2024-01-26       2024-01-27
# 766       2024-01-27       2024-01-27
# 768       2024-01-28       2024-01-28
# 772       2024-02-01       2024-02-01
# 773       2024-02-02       2024-02-02
# 774       2024-02-02       2024-02-02
# 778       2024-02-03       2024-02-03
# 779       2024-02-03       2024-02-03
# 781       2024-02-03       2024-02-03
# 783       2024-02-04       2024-02-04
# 785       2024-02-04       2024-02-04
# 786       2024-02-04       2024-02-04
# 787       2024-02-05       2024-02-05
# 794       2024-02-08       2024-02-08
# 795       2024-02-08       2024-02-08
# 797       2024-02-09       2024-02-09
# 798       2024-02-09       2024-02-09
# 799       2024-02-09       2024-02-09
# 800       2024-02-10       2024-02-10
# 801       2024-02-10       2024-02-10
# 805       2024-02-12       2024-02-12
# 808       2024-02-13       2024-02-13
# 816       2024-02-16       2024-02-17
# 818       2024-02-17       2024-02-17
# 819       2024-02-17       2024-02-17
# 820       2024-02-17       2024-02-17
# 821       2024-02-17       2024-02-17
# 822       2024-02-19       2024-02-19
# 824       2024-02-19       2024-02-19
# 825       2024-02-19       2024-02-19
# 828       2024-02-21       2024-02-21
# 830       2024-02-22       2024-02-22
# 831       2024-02-22       2024-02-22
# 832       2024-02-22       2024-02-22
# 834       2024-02-23       2024-02-23
# 836       2024-02-25       2024-02-25
# 842       2024-02-27       2024-02-27
# 843       2024-02-29       2024-02-29
# 846       2024-03-05       2024-03-05
# 849       2024-03-06       2024-03-06
# 852       2024-03-09       2024-03-09
# 854       2024-03-09       2024-03-09
# 869       2024-03-19       2024-03-19
# 871       2024-03-20       2024-03-20
# 872       2024-03-21       2024-03-21
# 874       2024-03-22       2024-03-22
# 878       2024-03-24       2024-03-24
# 879       2024-03-24       2024-03-24
# 880       2024-03-24       2024-03-24
# 882       2024-03-24       2024-03-25
# 885       2024-03-26       2024-03-26
# 886       2024-03-26       2024-03-26
# 887       2024-03-26       2024-03-27
# 888       2024-03-27       2024-03-27
# 889       2024-03-29       2024-03-29
# 890       2024-03-30       2024-03-30
# 893       2024-03-30       2024-03-30
# 895       2024-03-30       2024-03-30
# 896       2024-03-31       2024-03-31
# 898       2024-03-31       2024-03-31
# 899       2024-04-01       2024-04-01
# 900       2024-04-01       2024-04-01
# 904       2024-04-03       2024-04-03
# 910       2024-04-06       2024-04-06
# 911       2024-04-07       2024-04-07
# 913       2024-04-07       2024-04-07
# 914       2024-04-08       2024-04-08
# 915       2024-04-08       2024-04-08
# 919       2024-04-09       2024-04-09
# 920       2024-04-11       2024-04-11
# 922       2024-04-12       2024-04-12
# 924       2024-04-13       2024-04-13
# 925       2024-04-14       2024-04-14
# 928       2024-04-15       2024-04-15
# 929       2024-04-15       2024-04-15
# 930       2024-04-17       2024-04-17
# 931       2024-04-17       2024-04-17
# 935       2024-04-19       2024-04-19
# 938       2024-04-21       2024-04-21
# 943       2024-04-23       2024-04-23
# 944       2024-04-23       2024-04-23
# 946       2024-04-26       2024-04-26
# 947       2024-04-26       2024-04-26
# 949       2024-04-26       2024-04-26
# 950       2024-04-27       2024-04-27
# 951       2024-04-28       2024-04-28
# 952       2024-04-28       2024-04-28
# 953       2024-04-30       2024-04-30
# 956       2024-05-01       2024-05-01
# 958       2024-05-02       2024-05-02
# 960       2024-05-03       2024-05-03
# 961       2024-05-03       2024-05-03
# 962       2024-05-03       2024-05-03
# 963       2024-05-04       2024-05-04
# 964       2024-05-05       2024-05-05
# 965       2024-05-05       2024-05-05
# 966       2024-05-05       2024-05-05
# 967       2024-05-05       2024-05-05
# 968       2024-05-05       2024-05-05
# 969       2024-05-05       2024-05-05
# 970       2024-05-06       2024-05-06
# 971       2024-05-06       2024-05-06
# 972       2024-05-08       2024-05-08
# 973       2024-05-08       2024-05-08
# 974       2024-05-08       2024-05-08
# 975       2024-05-09       2024-05-09
# 976       2024-05-09       2024-05-09
# 978       2024-05-10       2024-05-10
# 979       2024-05-10       2024-05-11
# 980       2024-05-11       2024-05-11
# 981       2024-05-11       2024-05-11
# 983       2024-05-11       2024-05-12
# 984       2024-05-12       2024-05-12
# 987       2024-05-13       2024-05-13
# 988       2024-05-13       2024-05-13
# 990       2024-05-14       2024-05-14
# 991       2024-05-14       2024-05-14
# 995       2024-05-17       2024-05-17
# 996       2024-05-17       2024-05-17
# 998       2024-05-17       2024-05-17
# 999       2024-05-17       2024-05-18
# 1001      2024-05-18       2024-05-19
# 1004      2024-05-22       2024-05-22
# 1006      2024-05-23       2024-05-23
# 1007      2024-05-23       2024-05-23
# 1008      2024-05-24       2024-05-24
# 1009      2024-05-25       2024-05-25
# 1010      2024-05-25       2024-05-25
# 1011      2024-05-25       2024-05-25
# 1012      2024-05-25       2024-05-25
# 1014      2024-05-25       2024-05-25
# 1016      2024-05-27       2024-05-27
# 1017      2024-05-27       2024-05-27
# 1018      2024-05-27       2024-05-27
# 1019      2024-05-28       2024-05-28
# 1020      2024-05-29       2024-05-29
# 1022      2024-05-31       2024-05-31
# 1023      2024-05-31       2024-05-31
# 1026      2024-06-01       2024-06-01
# 1028      2024-06-02       2024-06-02
# 1029      2024-06-02       2024-06-02
# 1033      2024-06-03       2024-06-03
# 1038      2024-06-03       2024-06-03
# 1040      2024-06-04       2024-06-04
# 1041      2024-06-05       2024-06-05
# 1042      2024-06-05       2024-06-05
# 1043      2024-06-05       2024-06-05
# 1045      2024-06-05       2024-06-05
# 1047      2024-06-06       2024-06-06
# 1050      2024-06-06       2024-06-06
# 1053      2024-06-08       2024-06-08
# 1055      2024-06-09       2024-06-09
# 1057      2024-06-10       2024-06-10
# 1058      2024-06-12       2024-06-12
# 1059      2024-06-12       2024-06-12
# 1060      2024-06-12       2024-06-12
# 1061      2024-06-12       2024-06-12
# 1062      2024-06-14       2024-06-14
# 1063      2024-06-14       2024-06-14
# 1067      2024-06-16       2024-06-16
# 1069      2024-06-17       2024-06-17
# 1070      2024-06-17       2024-06-17
# 1071      2024-06-17       2024-06-17
# 1072      2024-06-17       2024-06-17
# 1073      2024-06-18       2024-06-18
# 1075      2024-06-19       2024-06-19
# 1076      2024-06-19       2024-06-19
# 1077      2024-06-20       2024-06-20
# 1078      2024-06-20       2024-06-20
# 1079      2024-06-20       2024-06-20
# 1081      2024-06-20       2024-06-20
# 1084      2024-06-21       2024-06-21
# 1086      2024-06-22       2024-06-22
# 1089      2024-06-22       2024-06-22
# 1094      2024-06-23       2024-06-24
# 1103      2024-06-24       2024-06-24
# 1107      2024-06-26       2024-06-26
# 1108      2024-06-27       2024-06-27
# 1109      2024-06-28       2024-06-28
# 1112      2024-06-29       2024-06-29
# 1118      2024-07-01       2024-07-01
# 1120      2024-07-01       2024-07-01
# 1125      2024-07-02       2024-07-02
# 1126      2024-07-02       2024-07-02
# 1127      2024-07-02       2024-07-02
# 1129      2024-07-03       2024-07-03
# 1130      2024-07-04       2024-07-04
# 1132      2024-07-05       2024-07-05
# 1134      2024-07-05       2024-07-06
# 1135      2024-07-06       2024-07-06
# 1136      2024-07-06       2024-07-06
# 1137      2024-07-06       2024-07-06
# 1138      2024-07-07       2024-07-07
# 1140      2024-07-08       2024-07-08
# 1141      2024-07-09       2024-07-09
# 1144      2024-07-11       2024-07-11
# 1147      2024-07-13       2024-07-13
# 1148      2024-07-13       2024-07-13
# 1150      2024-07-13       2024-07-13
# 1152      2024-07-13       2024-07-14
# 1153      2024-07-14       2024-07-14
# 1154      2024-07-15       2024-07-15
# 1155      2024-07-15       2024-07-15
# 1157      2024-07-16       2024-07-16
# 1163      2024-07-17       2024-07-17
# 1165      2024-07-18       2024-07-18
# 1166      2024-07-18       2024-07-18
# 1168      2024-07-18       2024-07-18
# 1169      2024-07-18       2024-07-18
# 1170      2024-07-19       2024-07-19
# 1175      2024-07-21       2024-07-21
# 1177      2024-07-21       2024-07-22
# 1179      2024-07-22       2024-07-22
# 1181      2024-07-23       2024-07-23
# 1182      2024-07-23       2024-07-23
# 1183      2024-07-23       2024-07-24
# 1184      2024-07-24       2024-07-24
# 1185      2024-07-24       2024-07-24
# 1187      2024-07-25       2024-07-25
# 1192      2024-07-27       2024-07-27
# 1194      2024-07-28       2024-07-28
# 1195      2024-07-28       2024-07-28
# 1196      2024-07-28       2024-07-28
# 1197      2024-07-29       2024-07-29
# 1199      2024-07-30       2024-07-30
# 1202      2024-07-31       2024-07-31
# 1203      2024-07-31       2024-07-31
# 1204      2024-07-31       2024-07-31
# 1206      2024-08-01       2024-08-01
# 1207      2024-08-01       2024-08-01
# 1209      2024-08-01       2024-08-01
# 1210      2024-08-02       2024-08-02
# 1211      2024-08-02       2024-08-02
# 1212      2024-08-02       2024-08-02
# 1214      2024-08-03       2024-08-03
# 1216      2024-08-03       2024-08-03
# 1221      2024-08-06       2024-08-06
# 1222      2024-08-06       2024-08-06
# 1224      2024-08-07       2024-08-07
# 1225      2024-08-07       2024-08-07
# 1226      2024-08-08       2024-08-08
# 1227      2024-08-08       2024-08-08
# 1228      2024-08-08       2024-08-08
# 1229      2024-08-08       2024-08-08
# 1230      2024-08-09       2024-08-09
# 1236      2024-08-12       2024-08-12
# 1237      2024-08-12       2024-08-12
# 1241      2024-08-13       2024-08-13
# 1242      2024-08-13       2024-08-13
# 1243      2024-08-13       2024-08-13
# 1244      2024-08-13       2024-08-13
# 1245      2024-08-14       2024-08-14
# 1246      2024-08-14       2024-08-14
# 1247      2024-08-14       2024-08-14
# 1248      2024-08-14       2024-08-15
# 1251      2024-08-15       2024-08-16
# 1253      2024-08-15       2024-08-16
# 1254      2024-08-16       2024-08-16
# 1258      2024-08-17       2024-08-17
# 1259      2024-08-17       2024-08-17
# 1260      2024-08-17       2024-08-17
# 1261      2024-08-17       2024-08-17
# 1262      2024-08-18       2024-08-18
# 1266      2024-08-19       2024-08-19
# 1269      2024-08-20       2024-08-20
# 1273      2024-08-21       2024-08-21
# 1274      2024-08-21       2024-08-22
# 1275      2024-08-22       2024-08-22
# 1276      2024-08-22       2024-08-22
# 1277      2024-08-22       2024-08-22
# 1278      2024-08-22       2024-08-22
# 1279      2024-08-24       2024-08-24
# 1280      2024-08-24       2024-08-25
# 1281      2024-08-25       2024-08-26
# 1282      2024-08-27       2024-08-27
# 1283      2024-08-27       2024-08-27
# 1286      2024-08-28       2024-08-28
# 1287      2024-08-28       2024-08-28
# 1289      2024-08-30       2024-08-30
# 1291      2024-08-30       2024-08-30
# 1292      2024-08-31       2024-08-31
# 1293      2024-09-01       2024-09-01
# 1294      2024-09-01       2024-09-01
# 1296      2024-09-02       2024-09-02
# 1299      2024-09-03       2024-09-03
# 1300      2024-09-03       2024-09-03
# 1301      2024-09-03       2024-09-03
# 1310      2024-09-07       2024-09-07
# 1312      2024-09-07       2024-09-07
# 1313      2024-09-08       2024-09-08
# 1314      2024-09-09       2024-09-09
# 1316      2024-09-09       2024-09-09
# 1320      2024-09-10       2024-09-10
# 1321      2024-09-10       2024-09-10
# 1323      2024-09-11       2024-09-11
# 1331      2024-09-14       2024-09-14
# 1333      2024-09-15       2024-09-15
# 1335      2024-09-16       2024-09-16
# 1336      2024-09-16       2024-09-16
# 1338      2024-09-17       2024-09-17
# 1339      2024-09-17       2024-09-17
# 1340      2024-09-17       2024-09-17
# 1341      2024-09-17       2024-09-17
# 1343      2024-09-17       2024-09-17
# 1345      2024-09-18       2024-09-18
# 1346      2024-09-18       2024-09-19
# 1347      2024-09-19       2024-09-19
# 1348      2024-09-19       2024-09-19
# 1349      2024-09-19       2024-09-20
# 1350      2024-09-19       2024-09-20
# 1355      2024-09-20       2024-09-20
# 1357      2024-09-21       2024-09-21
# 1358      2024-09-21       2024-09-21
# 1360      2024-09-22       2024-09-22
# 1361      2024-09-23       2024-09-23
# 1362      2024-09-25       2024-09-25
# 1363      2024-09-25       2024-09-25
# 1364      2024-09-25       2024-09-25
# 1365      2024-09-25       2024-09-25
# 1366      2024-09-26       2024-09-26
# 1367      2024-09-26       2024-09-26
# 1368      2024-09-27       2024-09-27
# 1374      2024-09-29       2024-09-29
# 1375      2024-09-29       2024-09-29
# 1376      2024-09-29       2024-09-29
# 1377      2024-09-29       2024-09-29
# 1379      2024-09-30       2024-09-30
# 1382      2024-09-30       2024-09-30
# 1387      2024-10-01       2024-10-02
# 1388      2024-10-01       2024-10-02
# 1389      2024-10-02       2024-10-02
# 1392      2024-10-02       2024-10-03
# 1394      2024-10-03       2024-10-03
# 1399      2024-10-04       2024-10-04
# 1401      2024-10-04       2024-10-04
# 1402      2024-10-04       2024-10-04
# 1403      2024-10-04       2024-10-05
# 1404      2024-10-05       2024-10-05
# 1405      2024-10-05       2024-10-05
# 1406      2024-10-05       2024-10-05
# 1408      2024-10-06       2024-10-06
# 1409      2024-10-07       2024-10-07
# 1411      2024-10-08       2024-10-08
# 1414      2024-10-08       2024-10-08
# 1416      2024-10-09       2024-10-09
# 1417      2024-10-09       2024-10-10
# 1419      2024-10-10       2024-10-10
# 1420      2024-10-12       2024-10-12
# 1421      2024-10-13       2024-10-13
# 1422      2024-10-13       2024-10-13
# 1423      2024-10-14       2024-10-14
# 1424      2024-10-15       2024-10-15
# 1425      2024-10-15       2024-10-15
# 1426      2024-10-15       2024-10-15
# 1427      2024-10-15       2024-10-15
# 1429      2024-10-16       2024-10-16
# 1430      2024-10-17       2024-10-17
# 1431      2024-10-17       2024-10-17
# 1433      2024-10-18       2024-10-18
# 1435      2024-10-18       2024-10-18
# 1437      2024-10-21       2024-10-21
# 1438      2024-10-21       2024-10-21
# 1439      2024-10-21       2024-10-21
# 1440      2024-10-21       2024-10-21
# 1441      2024-10-22       2024-10-22
# 1445      2024-10-23       2024-10-23
# 1446      2024-10-24       2024-10-24
# 1447      2024-10-24       2024-10-24
# 1448      2024-10-24       2024-10-24
# 1451      2024-10-25       2024-10-25
# 1452      2024-10-25       2024-10-25
# 1454      2024-10-27       2024-10-27
# 1459      2024-10-28       2024-10-28
# 1460      2024-10-28       2024-10-28
# 1462      2024-10-28       2024-10-28
# 1463      2024-10-29       2024-10-29
# 1468      2024-10-31       2024-10-31
# 1469      2024-10-31       2024-10-31
# 1470      2024-10-31       2024-10-31
# 1471      2024-10-31       2024-10-31
# 1472      2024-11-01       2024-11-01
# 1473      2024-11-01       2024-11-01
# 1476      2024-11-01       2024-11-01
# 1479      2024-11-02       2024-11-02
# 1480      2024-11-02       2024-11-02
# 1485      2024-11-04       2024-11-04
# 1492      2024-11-07       2024-11-07
# 1493      2024-11-07       2024-11-07
# 1494      2024-11-08       2024-11-08
# 1495      2024-11-08       2024-11-08
# 1496      2024-11-08       2024-11-08
# 1497      2024-11-08       2024-11-08
# 1502      2024-11-10       2024-11-10
# 1503      2024-11-10       2024-11-10
# 1504      2024-11-11       2024-11-11
# 1506      2024-11-11       2024-11-11
# 1508      2024-11-11       2024-11-12
# 1509      2024-11-11       2024-11-12
# 1510      2024-11-12       2024-11-12
# 1511      2024-11-13       2024-11-13
# 1512      2024-11-13       2024-11-13
# 1516      2024-11-14       2024-11-14
# 1518      2024-11-15       2024-11-15
# 1520      2024-11-16       2024-11-16
# 1522      2024-11-17       2024-11-17
# 1523      2024-11-17       2024-11-17
# 1524      2024-11-17       2024-11-17
# 1526      2024-11-17       2024-11-17
# 1528      2024-11-18       2024-11-18
# 1530      2024-11-19       2024-11-19
# 1531      2024-11-19       2024-11-19
# 1533      2024-11-20       2024-11-20
# 1536      2024-11-20       2024-11-20
# 1537      2024-11-20       2024-11-20
# 1540      2024-11-21       2024-11-21
# 1541      2024-11-21       2024-11-21
# 1542      2024-11-21       2024-11-21
# 1543      2024-11-21       2024-11-21
# 1544      2024-11-21       2024-11-21
# 1545      2024-11-21       2024-11-21
# 1546      2024-11-21       2024-11-21
# 1548      2024-11-22       2024-11-22
# 1549      2024-11-22       2024-11-22
# 1551      2024-11-22       2024-11-23
# 1553      2024-11-23       2024-11-23
# 1556      2024-11-23       2024-11-23
# 1557      2024-11-24       2024-11-24
# 1559      2024-11-24       2024-11-24
# 1560      2024-11-24       2024-11-24
# 1563      2024-11-25       2024-11-25
# 1564      2024-11-25       2024-11-25
# 1565      2024-11-25       2024-11-26
# 1566      2024-11-25       2024-11-26
# 1569      2024-11-27       2024-11-27
# 1570      2024-11-27       2024-11-27
# 1571      2024-11-27       2024-11-27
# 1574      2024-11-28       2024-11-28
# 1575      2024-11-28       2024-11-28
# 1578      2024-11-29       2024-11-29
# 1580      2024-11-29       2024-11-29
# 1582      2024-11-30       2024-11-30
# 1583      2024-11-30       2024-11-30
# 1584      2024-11-30       2024-11-30
# 1588      2024-12-03       2024-12-03
# 1589      2024-12-03       2024-12-04
# 1590      2024-12-04       2024-12-04
# 1591      2024-12-04       2024-12-04
# 1592      2024-12-06       2024-12-06
# 1593      2024-12-06       2024-12-06
# 1594      2024-12-06       2024-12-07
# 1595      2024-12-07       2024-12-07
# 1596      2024-12-07       2024-12-07
# 1597      2024-12-07       2024-12-07
# 1598      2024-12-07       2024-12-07
# 1600      2024-12-08       2024-12-08
# 1602      2024-12-09       2024-12-09
# 1607      2024-12-09       2024-12-09
# 1608      2024-12-10       2024-12-10
# 1609      2024-12-10       2024-12-10
# 1610      2024-12-10       2024-12-10
# 1616      2024-12-10       2024-12-10
# 1617      2024-12-11       2024-12-11
# 1618      2024-12-11       2024-12-11
# 1619      2024-12-11       2024-12-11
# 1620      2024-12-12       2024-12-12
# 1621      2024-12-13       2024-12-13
# 1622      2024-12-13       2024-12-13
# 1623      2024-12-13       2024-12-13
# 1627      2024-12-16       2024-12-17
# 1628      2024-12-16       2024-12-17
# 1629      2024-12-17       2024-12-17
# 1632      2024-12-17       2024-12-17
# 1633      2024-12-17       2024-12-17
# 1637      2024-12-18       2024-12-18
# 1638      2024-12-18       2024-12-18
# 1639      2024-12-18       2024-12-18
# 1640      2024-12-18       2024-12-18
# 1642      2024-12-19       2024-12-19
# 1643      2024-12-19       2024-12-19
# 1644      2024-12-21       2024-12-21
# 1646      2024-12-22       2024-12-22
# 1647      2024-12-22       2024-12-22
# 1649      2024-12-23       2024-12-23
# 1650      2024-12-24       2024-12-24
# 1651      2024-12-24       2024-12-24
# 1653      2024-12-24       2024-12-24
# 1654      2024-12-25       2024-12-25
# 1655      2024-12-25       2024-12-25
# 1660      2024-12-26       2024-12-26
# 1661      2024-12-27       2024-12-27
# 1667      2024-12-28       2024-12-28
# 1669      2024-12-29       2024-12-29
# 1671      2024-12-30       2024-12-30
# 1674      2024-12-31       2024-12-31
# 1675      2024-12-31       2024-12-31

# %%
# Vérifions si le item_status peut avoir une valeur différente de son "order_status" associé. On voit que c'est bien le cas :
df.groupby('item_status')['order_status'].unique().reset_index()
# Out:
#   item_status  order_status
# 0   Cancelled   [Cancelled]
# 1    Complete    [Complete]
# 2  Processing  [Processing]
# 3    Returned    [Returned]
# 4     Shipped     [Shipped]

# %% [markdown]
# # PARTIE 2 : EXPLORATION DESCRIPTIVE : Explorations descriptives : distributions (prix de vente, coût), contribution par marque, catégorie,ville, saisonnalité mensuelle, et comparaison 2024 vs 2023"
#
# ## HYPOTHESE PRINCIPALES:
# ### Compte tenu de la PARTIE 1, nous prendrons comme hypothèses que:
# ### - Le Chiffre d'Affaires se calcule sur les ventes avec un statut Complete, sauf si explicitement mentionné autrement
# ### - Pour classer les ventes par mois / année, nous prendrons en compte la date de livraison delivered_at.
# ### - L'objectif est de créer une page de graphiques pour la vue d'ensemble + une page de graphiques par dimension. Les graphiques seront sélectionnés de façon pertinente selon chaque dimension.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick
import matplotlib.cm as cm #permet d'obtenir une palette de couleurs distinctes (pas de couleur doublonnée dans un graphique)

# %%
from src.utils import kpi_CA
from src.utils import kpi_Margin
from src.utils import kpi_panier_moyen
from src.utils import kpi_tx_retour
from src.utils import kpi_tx_reachat
from src.utils import currency

# %%
# Création des années et mois dans df pour pouvoir créer les graphiques appropriés. 
df["year_created"]=df["item_created_at"].dt.year.astype('Int64')
df["month_created"]=df["item_created_at"].dt.month.astype('Int64')
df["year_month"]=df["item_created_at"].dt.to_period('M').astype(str)

#creation du df df_complete qui filtre sur les commandes livrées / non renvoyées
df_complete=df[df['order_status'] == "Complete"]
# Out:
# C:\Users\chd78002\AppData\Local\Temp\ipykernel_20560\593611976.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["year_month"]=df["item_created_at"].dt.to_period('M').astype(str)

# %% [markdown]
# ### VUE D'ENSEMBLE

# %%
# CREATION DE LA PAGE OVERVIEW :

#Configuration de la page 
fig = plt.figure(constrained_layout=False, figsize = (20,30))
gs = fig.add_gridspec(5, 3)
ax1=fig.add_subplot(gs[0:2, :])
ax2=fig.add_subplot(gs[2:4, :])
ax3=fig.add_subplot(gs[4, 0])
ax4=fig.add_subplot(gs[4, 1])
ax5=fig.add_subplot(gs[4, 2])

#PPREMIER GRAPHIQUE : CA 2024 VS 2023
CA_month= kpi_CA(df_complete,dimensions=["month_created","year_created"])

# Trier les mois correctement

CA_month = CA_month.sort_values(["month_created","year_created"])

#séparer les années
df_CA_2023= CA_month[CA_month["year_created"]==2023].copy()
df_CA_2024= CA_month[CA_month["year_created"]==2024].copy()

#calcul du YTD
df_CA_2023['CA_YTD'] = df_CA_2023['chiffre_affaires'].cumsum()
df_CA_2024['CA_YTD'] = df_CA_2024['chiffre_affaires'].cumsum()

#creation du graphique 
x= np.arange(len(df_CA_2023["month_created"]))
largeur = 0.35

# Barres
ax1.bar(x - largeur/2, df_CA_2023["chiffre_affaires"], width=largeur, label="CA 2023", color='#95b2c9')
ax1.bar(x + largeur/2, df_CA_2024["chiffre_affaires"], width=largeur, label="CA 2024", color='#075594')
ax1.set_xlabel("Mois")
ax1.set_ylabel("Chiffre d'affaires mensuel")
ax1.yaxis.set_major_formatter(currency) # on applique la fonction currency pour avoir le bon format de l'axe y
ax1.set_xticks(x)
ax1.set_xticklabels(df_CA_2023["month_created"].astype(str))

# Courbes cumulées (axe secondaire)
ax1_cum = ax1.twinx()
ax1_cum.plot(x, df_CA_2023["CA_YTD"], color="#6291b8", marker="o", linestyle="--", label="CA cumulé 2023")
ax1_cum.plot(x, df_CA_2024["CA_YTD"], color="#031A2E", marker="o", linestyle="--", label="CA cumulé 2024")
ax1_cum.set_ylabel("Chiffre d'affaires cumulé")
ax1_cum.yaxis.set_major_formatter(currency) # on applique la fonction currency pour avoir le bon format de l'axe y

# Légende combinée
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax1_cum.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="upper left")
ax1.set_title("Chiffre d'affaires mensuel et cumulatif 2024 vs 2023")


#Formattage du graphique 
ax1.grid(visible=True, which='major', axis='x')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.tick_params(axis='x', which='major', labelsize=12)
ax1_cum.spines['top'].set_visible(False)
ax1_cum.spines['right'].set_visible(False)
ax1_cum.spines['bottom'].set_visible(False)
ax1_cum.spines['left'].set_visible(False)


# SECONDE GRAPHIQUE : MARGE 2024 VS 2023

Margin_month= kpi_Margin(df_complete,dimensions=["month_created","year_created"])

# Trier les mois correctement
Margin_month = Margin_month.sort_values(["month_created","year_created"])

#séparer les années
df_Margin_2023= Margin_month[Margin_month["year_created"]==2023].copy()
df_Margin_2024= Margin_month[Margin_month["year_created"]==2024].copy()

#calcul du YTD
df_Margin_2023['MARGIN_YTD'] = df_Margin_2023['marge'].cumsum()
df_Margin_2024['MARGIN_YTD'] = df_Margin_2024['marge'].cumsum()

#creation du graphique 
x2= np.arange(len(df_Margin_2023["month_created"]))
largeur2 = 0.35

# Barres
ax2.bar(x2 - largeur2/2, df_Margin_2023["marge"], width=largeur2, label="Marge 2023", color='#95b2c9')
ax2.bar(x2 + largeur2/2, df_Margin_2024["marge"], width=largeur2, label="Marge 2024", color='#075594')
ax2.set_xlabel("Mois")
ax2.set_ylabel("Marge mensuelle")
ax2.set_xticks(x)
ax2.set_xticklabels(df_Margin_2023["month_created"].astype(str))
ax2.yaxis.set_major_formatter(currency) # on applique la fonction currency pour avoir le bon format de l'axe y

# Courbes cumulées (axe secondaire)
ax2_cum = ax2.twinx()
ax2_cum.plot(x, df_Margin_2023["MARGIN_YTD"], color="#6291b8", marker="o", linestyle="--", label="Marge cumulée 2023")
ax2_cum.plot(x, df_Margin_2024["MARGIN_YTD"], color="#031A2E", marker="o", linestyle="--", label="Marge cumulée 2024")
ax2_cum.set_ylabel("Marge cumulée")
ax2_cum.yaxis.set_major_formatter(currency) # on applique la fonction currency pour avoir le bon format de l'axe y

# Légende combinée
lines1, labels1 = ax2.get_legend_handles_labels()
lines2, labels2 = ax2_cum.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc="upper left")
ax2.set_title("Marge mensuelle et cumulative 2024 vs 2023")

#Formattage du graphique 
ax2.grid(visible=True, which='major', axis='x')
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.tick_params(axis='x', which='major', labelsize=12)
ax2_cum.spines['top'].set_visible(False)
ax2_cum.spines['right'].set_visible(False)
ax2_cum.spines['bottom'].set_visible(False)
ax2_cum.spines['left'].set_visible(False)


# TROISIEME GRAPHIQUE : PANIER MOYEN 2024 VS 2023

PM_year=kpi_panier_moyen(df_complete,dimensions=["year_created"])
#séparer les années
PM_2023= PM_year[PM_year["year_created"]==2023].copy()
PM_2024= PM_year[PM_year["year_created"]==2024].copy()


# Barres

ax3.bar(PM_2023["year_created"],PM_2023["panier_moyen"],color='#95b2c9',label="2023")
ax3.bar(PM_2024["year_created"],PM_2024["panier_moyen"],color='#075594',label="2024")

# Mise en forme
ax3.set_xticks([2023, 2024]) #on force des entiers (sinon dans la légende on a 2022.75, 2023.25, etc)
ax3.set_xticklabels(["2023", "2024"])#on force des entiers (sinon dans la légende on a 2022.75, 2023.25, etc)
ax3.set_title("Panier moyen par année")
ax3.yaxis.set_major_formatter(currency) # on applique la fonction currency pour avoir le bon format de l'axe 
ax3.set_ylim(0, 100) # force les limites de l'axe 
ax3.legend()

ax3.spines['top'].set_visible(False)
#ax3.spines['right'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.spines['left'].set_visible(False)

# QUATRIEME GRAPHIQUE : TAUX RACHAT 2024 VS 2023

#séparer les années
TREA_2023 = kpi_tx_reachat(df_complete, 2023)
TREA_2024 = kpi_tx_reachat(df_complete, 2024)

x = [0, 1]
values = [TREA_2023, TREA_2024]

ax4.bar(x[0], values[0], color='#95b2c9', label="2023")
ax4.bar(x[1], values[1], color='#075594', label="2024")

# ticks cohérents avec x
ax4.set_xticks(x)
ax4.set_xticklabels(["2023", "2024"])

ax4.set_title("Taux de rachat par année")
ax4.legend()

ax4.spines['top'].set_visible(False)
#ax4.spines['right'].set_visible(False)
ax4.spines['bottom'].set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1)) # permet d'avoir l'axe des y en %




#CINQUIEME GRAPHIQUE : TAUX RETOUR 2024 VS 2023
TR_year=kpi_tx_retour(df,dimensions=["year_created"]) # on utilise df et pas df_complete puisqu'on a besoin des statuts Returned
#séparer les années
TR_2023= TR_year[TR_year["year_created"]==2023].copy()
TR_2024= TR_year[TR_year["year_created"]==2024].copy()

# Barres

ax5.bar(TR_2023["year_created"],TR_2023["taux_retour"],color="#c9bf95",label="2023")
ax5.bar(TR_2024["year_created"],TR_2024["taux_retour"],color="orange",label="2024")

# Mise en forme
ax5.set_xticks([2023, 2024]) #on force des entiers (sinon dans la légende on a 2022.75, 2023.25, etc)
ax5.set_xticklabels(["2023", "2024"])#on force des entiers (sinon dans la légende on a 2022.75, 2023.25, etc)
ax5.set_title("Taux de retour par année")
ax5.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1)) # permet d'avoir l'axe des y en %

ax5.legend()

ax5.spines['top'].set_visible(False)
ax5.spines['right'].set_visible(False)
ax5.spines['bottom'].set_visible(False)
ax5.spines['left'].set_visible(False)

plt.tight_layout() #ajuste automatiquement les marges

# %%
marge_category=kpi_Margin(df,"category")
print(marge_category)
# Out:
#                          category        marge
# 0                     Accessories  1995.231498
# 1                          Active  2307.029758
# 2               Blazers & Jackets  2698.364770
# 3                   Clothing Sets    66.534511
# 4                         Dresses  5052.312019
# 5   Fashion Hoodies & Sweatshirts  2854.825092
# 6                       Intimates  3884.254060
# 7                           Jeans  3946.895085
# 8             Jumpsuits & Rompers   393.679323
# 9                        Leggings   461.629349
# 10                      Maternity  2418.630206
# 11              Outerwear & Coats  5598.698643
# 12                 Pants & Capris  2113.400021
# 13                           Plus  1712.822524
# 14                         Shorts  1581.242493
# 15                         Skirts  1503.087250
# 16                 Sleep & Lounge  1984.147517
# 17                Socks & Hosiery   579.528712
# 18                          Suits   689.641533
# 19                       Sweaters  2466.383389
# 20                           Swim  3608.911331
# 21                    Tops & Tees  1716.850007

# %% [markdown]
# ### ANALYSE PAR CATEGORIE

# %%
#CREATION DE LA PAGE D'ANALYSE PAR CATEGORIE

fig = plt.figure(constrained_layout=False, figsize = (20,30))
gs = fig.add_gridspec(5, 2)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1,1])

ax5 = fig.add_subplot(gs[2, 0])
ax6 = fig.add_subplot(gs[2,1])

ax7=fig.add_subplot(gs[3:,0:])


#Première ligne : indicateurs du Chiffre d'Affaires
#ax1 = Top CA 
top_CA_category=kpi_CA(df_complete, ['category'])
top_CA_category = top_CA_category.sort_values(by='chiffre_affaires', ascending=True) #classement des catégories par CA
top_CA_category = top_CA_category.set_index('category') # category devient l'index
top_CA_category.plot(kind='barh',  ax=ax1)
ax1.set_title("Classement des catégories par chiffre d'affaire \n sur l'ensemble de la période")
ax1.set_xlabel("Chiffre d'Affaires")
ax1.set_ylabel("Catégorie")
ax1.xaxis.set_major_formatter(currency) # on applique la fonction currency pour avoir le bon format de l'axe x

#Formattage du graphique 
ax1.grid(visible=True, which='major', axis='x')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.xaxis.set_major_formatter(currency)
ax1.tick_params(axis='x', which='major', labelsize=12)


#ax2= Growth CA
# Création du pivot des chiffres d'affaires sur df_complete (order "Complete" + exclusion de 2025), on passe en pivot et on traite les éventuelles valeurs N/A (même s'il n'y en a pas a priori)
topCA_cat_year_pivot = (kpi_CA(df_complete, ['category', "year_created"]).pivot(index='category', columns='year_created', values='chiffre_affaires').fillna(0))

#Calcul de la croissance 2024 vs 2023
growthCA = topCA_cat_year_pivot[2024] - topCA_cat_year_pivot[2023]

# Tri décroissant par growth en valeur absolue
topCA_cat_year_pivot_sorted = topCA_cat_year_pivot.loc[growthCA.sort_values(ascending=False).index]

#Tracer le bar histogramme
colors2 = ['#95b2c9', '#075594']
chart2=topCA_cat_year_pivot_sorted.plot(kind='barh', color=colors2, ax=ax2)

# on trace la ligne rouge qui délimite le growth négatif
negative_growth = growthCA.sort_values(ascending=False) # trie le growth en décroissant
if (negative_growth < 0).any(): # crée une série booléenne indiquant quelles catégories ont une croissance négative, renvoie True si au moisn une est négative
    first_negative_cat = negative_growth[negative_growth < 0].index[0]  # prend la première catégorie dans la série triée qui a une croissance négative.
    y_position = topCA_cat_year_pivot_sorted.index.get_loc(first_negative_cat) - 0.5 # -0.5 car décale la ligne de 0,5 pour qu’elle soit entre les barres et pas par-dessus
    ax2.axhline(y=y_position, color='red', linestyle='--', linewidth=2, label='Growth négatif') # trace la ligne

# Labels et titre
ax2.set_title("Top catégories \n Croissance du Chiffre d'affaires 2024 vs 2023")
ax2.set_xlabel("Chiffre d'affaires")
ax2.set_ylabel("Catégories")
ax2.invert_yaxis()  # catégorie la plus haute en haut
ax2.legend(title=None) 
chart2.xaxis.set_major_formatter(currency)

#Formattage du graphique 
ax2.grid(visible=True, which='major', axis='x')
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.xaxis.set_major_formatter(currency)
ax2.tick_params(axis='x', which='major', labelsize=12)



#ax3 = Top Marge
topM_category=kpi_Margin(df_complete, ['category'])
topM_category = topM_category.sort_values(by='marge', ascending=True)
topM_category = topM_category.set_index('category')
topM_category.plot(kind='barh',  ax=ax3)
ax3.set_title("Classement des catégories par Marge Brute \n sur l'ensemble de la période")
ax3.set_xlabel("Marge Brute")
ax3.set_ylabel("Catégorie")
ax3.xaxis.set_major_formatter(currency)

#Formattage du graphique 
ax3.grid(visible=True, which='major', axis='x')
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.xaxis.set_major_formatter(currency)
ax3.tick_params(axis='x', which='major', labelsize=12)


#ax4= Growth CA
# Création du pivot de la Marge Brute sur df_complete (order "Complete" + exclusion de 2025), on passe en pivot et on traite les éventuelles valeurs N/A (même s'il n'y en a pas a priori)
topM_cat_year_pivot = (kpi_Margin(df_complete, ['category', "year_created"]).pivot(index='category', columns='year_created', values='marge').fillna(0))

#Calcul de la croissance 2024 vs 2023
growthM = topM_cat_year_pivot[2024] - topM_cat_year_pivot[2023]

# Tri décroissant par growth en valeur absolue
topM_cat_year_pivot_sorted = topM_cat_year_pivot.loc[growthM.sort_values(ascending=False).index]

#Tracer le bar histogramme
colors4 = ['#95b2c9', '#075594']
chart4=topM_cat_year_pivot_sorted.plot(kind='barh', color=colors4, ax=ax4)

# on trace la ligne rouge qui délimite le growth négatif
negative_growth = growthM.sort_values(ascending=False) # trie le growth en décroissant
if (negative_growth < 0).any(): # crée une série booléenne indiquant quelles catégories ont une croissance négative, renvoie True si au moisn une est négative
    first_negative_cat = negative_growth[negative_growth < 0].index[0]  # prend la première catégorie dans la série triée qui a une croissance négative.
    y_position = topM_cat_year_pivot_sorted.index.get_loc(first_negative_cat) - 0.5 # -0.5 car décale la ligne de 0,5 pour qu’elle soit entre les barres et pas par-dessus
    ax4.axhline(y=y_position, color='red', linestyle='--', linewidth=2, label='Growth négatif') # trace la ligne

# Labels et titre
ax4.set_title("Top catégories \n Croissance de la Marge Brute 2024 vs 2023")
ax4.set_xlabel("Marge Brute")
ax4.set_ylabel("Catégories")
ax4.invert_yaxis()  # catégorie la plus haute en haut
ax4.legend(title=None) 
chart4.xaxis.set_major_formatter(currency)

#Formattage du graphique 
ax4.grid(visible=True, which='major', axis='x')
ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.spines['bottom'].set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.xaxis.set_major_formatter(currency)
ax4.tick_params(axis='x', which='major', labelsize=12)



#ax5 = Top Panier Moyen
top_PM_category=kpi_panier_moyen(df_complete, ['category'])
top_PM_category = top_PM_category.sort_values(by='panier_moyen', ascending=True)
top_PM_category = top_PM_category.set_index('category')
top_PM_category.plot(kind='barh',  ax=ax5)

#ajout d'une barre pour montrer la valeur mediane du panier moyen:
median_PM = top_PM_category['panier_moyen'].median()
ax5.axvline(x=median_PM, color='red', linestyle='--', linewidth=2, label=f"Médiane : {median_PM:,.0f}€")

ax5.set_title("Classement des catégories par panier moyen \n sur l'ensemble de la période")
ax5.set_xlabel("Panier Moyen")
ax5.set_ylabel("Catégorie")
ax5.xaxis.set_major_formatter(currency)

#Formattage du graphique 
ax5.grid(visible=True, which='major', axis='x')
ax5.spines['top'].set_visible(False)
ax5.spines['right'].set_visible(False)
ax5.spines['bottom'].set_visible(False)
ax5.spines['left'].set_visible(False)
ax5.xaxis.set_major_formatter(currency)
ax5.tick_params(axis='x', which='major', labelsize=12)
ax5.legend(title=None) 



#ax6 = Top Taux de retour --> cette fois on applique la fonction sur df et non sur df_complete puisque nécessaire pour le calcul du taux de retour
top_TR_category=kpi_tx_retour(df, ['category'])
top_TR_category = top_TR_category.sort_values(by='taux_retour', ascending=False)
top_TR_category = top_TR_category.set_index('category')
top_TR_category.plot(kind='barh', color="#FF934F", ax=ax6)
ax6.set_xlim(0, top_TR_category['taux_retour'].max() * 1.1)

#ajout d'une barre pour montrer la valeur mediane du taux de retour:
median_TR = top_TR_category['taux_retour'].median()
ax6.axvline(x=median_TR, color='red', linestyle='--', linewidth=2, label=f"Médiane : {median_TR*100:.1f}%")  # affichée en %

ax6.set_title("Classement décroissant des catégories par taux de retour \n sur l'ensemble de la période")
ax6.set_xlabel("Taux de retour (%)")
ax6.set_ylabel("Catégorie")

#Formattage du graphique 
ax6.grid(visible=True, which='major', axis='x')
ax6.spines['top'].set_visible(False)
ax6.spines['right'].set_visible(False)
ax6.spines['bottom'].set_visible(False)
ax6.spines['left'].set_visible(False)
ax6.tick_params(axis='x', which='major', labelsize=12)
ax6.legend(title=None)
ax6.xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1)) # permet d'avoir l'axe des x en %


#ax7 : Heatmap -> saisonalité du chiffre d'affaire par mois par catégorie
ca_month_category = kpi_CA(df_complete,['year_month', 'category'])
pivot_ca = ca_month_category.pivot(index='year_month',columns='category', values='chiffre_affaires').fillna(0)
pivot_ca = pivot_ca.sort_index()
pivot_heatmap = ca_month_category.pivot(index='category', columns='year_month', values='chiffre_affaires').fillna(0)
total_ca = pivot_heatmap.sum(axis=1)
pivot_heatmap_sorted = pivot_heatmap.loc[total_ca.sort_values(ascending=False).index]

sns.heatmap(pivot_heatmap_sorted, cmap="YlGnBu", linewidths=0.5, annot=True, fmt=".0f", ax=ax7)
ax7.set_title("Saisonnalité du chiffre d'affaires par catégorie")
ax7.set_xlabel("Mois")
ax7.set_ylabel("Catégorie")

#Formattage du graphique 

ax7.spines['top'].set_visible(False)
ax7.spines['right'].set_visible(False)
ax7.spines['bottom'].set_visible(False)
ax7.spines['left'].set_visible(False)


plt.tight_layout() #ajuste automatiquement les marges






# ax1

# %% [markdown]
# ### ANALYSE PAR REGION

# %%
#CREATION DE LA PAGE D'ANALYSE PAR REGION

fig = plt.figure(constrained_layout=False, figsize = (20,30))
gs = fig.add_gridspec(5, 2)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1,1])

ax5 = fig.add_subplot(gs[2, 0])
ax6 = fig.add_subplot(gs[2,1])

ax7=fig.add_subplot(gs[3:,0:])

#Première ligne : indicateurs du Chiffre d'Affaires
#ax1 = Top CA par state & category
top_CA_State=kpi_CA(df_complete, ['state']) 
top_CA_State = top_CA_State.sort_values(by='chiffre_affaires', ascending=True) #classement des Régions par CA
top_CA_State = top_CA_State.set_index('state') # State devient l'index
top_CA_State.plot(kind='barh', ax=ax1)
ax1.set_title("Classement des Régions par chiffre d'affaire \n sur l'ensemble de la période")
ax1.set_xlabel("Chiffre d'Affaires")
ax1.set_ylabel("Région")
ax1.xaxis.set_major_formatter(currency) # on applique la fonction currency pour avoir le bon format de l'axe x

#Formattage du graphique 
ax1.grid(visible=True, which='major', axis='x')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.xaxis.set_major_formatter(currency)
ax1.tick_params(axis='x', which='major', labelsize=12)

#ax2= Growth CA
# Création du pivot des chiffres d'affaires sur df_complete (order "Complete" + exclusion de 2025), on passe en pivot et on traite les éventuelles valeurs N/A (même s'il n'y en a pas a priori)
topCA_cat_year_pivot = (kpi_CA(df_complete, ['state', "year_created"]).pivot(index='state', columns='year_created', values='chiffre_affaires').fillna(0))

#Calcul de la croissance 2024 vs 2023
growthCA = topCA_cat_year_pivot[2024] - topCA_cat_year_pivot[2023]

# Tri décroissant par growth en valeur absolue
topCA_cat_year_pivot_sorted = topCA_cat_year_pivot.loc[growthCA.sort_values(ascending=False).index]

#Tracer le bar histogramme
colors2 = ['#95b2c9', '#075594']
chart2=topCA_cat_year_pivot_sorted.plot(kind='barh', color=colors2, ax=ax2)

# on trace la ligne rouge qui délimite le growth négatif
negative_growth = growthCA.sort_values(ascending=False) # trie le growth en décroissant
if (negative_growth < 0).any(): # crée une série booléenne indiquant quelles Régions ont une croissance négative, renvoie True si au moisn une est négative
    first_negative_cat = negative_growth[negative_growth < 0].index[0]  # prend la première Région dans la série triée qui a une croissance négative.
    y_position = topCA_cat_year_pivot_sorted.index.get_loc(first_negative_cat) - 0.5 # -0.5 car décale la ligne de 0,5 pour qu’elle soit entre les barres et pas par-dessus
    ax2.axhline(y=y_position, color='red', linestyle='--', linewidth=2, label='Growth négatif') # trace la ligne

# Labels et titre
ax2.set_title("Top Régions \n Croissance du Chiffre d'affaires 2024 vs 2023")
ax2.set_xlabel("Chiffre d'affaires")
ax2.set_ylabel("Régions")
ax2.invert_yaxis()  # Région la plus haute en haut
ax2.legend(title=None) 
chart2.xaxis.set_major_formatter(currency)

#Formattage du graphique 
ax2.grid(visible=True, which='major', axis='x')
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.xaxis.set_major_formatter(currency)
ax2.tick_params(axis='x', which='major', labelsize=12)


#ax3 = Top Marge
topM_State=kpi_Margin(df_complete, ['state'])
topM_State = topM_State.sort_values(by='marge', ascending=True)
topM_State = topM_State.set_index('state')
topM_State.plot(kind='barh',  ax=ax3)
ax3.set_title("Classement des Régions par Marge Brute \n sur l'ensemble de la période")
ax3.set_xlabel("Marge Brute")
ax3.set_ylabel("Région")
ax3.xaxis.set_major_formatter(currency)

#Formattage du graphique 
ax3.grid(visible=True, which='major', axis='x')
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.xaxis.set_major_formatter(currency)
ax3.tick_params(axis='x', which='major', labelsize=12)

#ax4= Growth CA
# Création du pivot de la Marge Brute sur df_complete (order "Complete" + exclusion de 2025), on passe en pivot et on traite les éventuelles valeurs N/A (même s'il n'y en a pas a priori)
topM_cat_year_pivot = (kpi_Margin(df_complete, ['state', "year_created"]).pivot(index='state', columns='year_created', values='marge').fillna(0))

#Calcul de la croissance 2024 vs 2023
growthM = topM_cat_year_pivot[2024] - topM_cat_year_pivot[2023]

# Tri décroissant par growth en valeur absolue
topM_cat_year_pivot_sorted = topM_cat_year_pivot.loc[growthM.sort_values(ascending=False).index]

#Tracer le bar histogramme
colors4 = ['#95b2c9', '#075594']
chart4=topM_cat_year_pivot_sorted.plot(kind='barh', color=colors4, ax=ax4)

# on trace la ligne rouge qui délimite le growth négatif
negative_growth = growthM.sort_values(ascending=False) # trie le growth en décroissant
if (negative_growth < 0).any(): # crée une série booléenne indiquant quelles Régions ont une croissance négative, renvoie True si au moisn une est négative
    first_negative_cat = negative_growth[negative_growth < 0].index[0]  # prend la première Région dans la série triée qui a une croissance négative.
    y_position = topM_cat_year_pivot_sorted.index.get_loc(first_negative_cat) - 0.5 # -0.5 car décale la ligne de 0,5 pour qu’elle soit entre les barres et pas par-dessus
    ax4.axhline(y=y_position, color='red', linestyle='--', linewidth=2, label='Growth négatif') # trace la ligne

# Labels et titre
ax4.set_title("Top Régions \n Croissance de la Marge Brute 2024 vs 2023")
ax4.set_xlabel("Marge Brute")
ax4.set_ylabel("Régions")
ax4.invert_yaxis()  # Région la plus haute en haut
ax4.legend(title=None) 
chart4.xaxis.set_major_formatter(currency)

#Formattage du graphique 
ax4.grid(visible=True, which='major', axis='x')
ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.spines['bottom'].set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.xaxis.set_major_formatter(currency)
ax4.tick_params(axis='x', which='major', labelsize=12)


#ax5 = Top Panier Moyen
top_PM_State=kpi_panier_moyen(df_complete, ['state'])
top_PM_State = top_PM_State.sort_values(by='panier_moyen', ascending=True)
top_PM_State = top_PM_State.set_index('state')
top_PM_State.plot(kind='barh',  ax=ax5)

#ajout d'une barre pour montrer la valeur mediane du panier moyen:
median_PM = top_PM_State['panier_moyen'].median()
ax5.axvline(x=median_PM, color='red', linestyle='--', linewidth=2, label=f"Médiane : {median_PM:,.0f}€")

ax5.set_title("Classement des Régions par panier moyen \n sur l'ensemble de la période")
ax5.set_xlabel("Panier Moyen")
ax5.set_ylabel("Région")
ax5.xaxis.set_major_formatter(currency)

#Formattage du graphique 
ax5.grid(visible=True, which='major', axis='x')
ax5.spines['top'].set_visible(False)
ax5.spines['right'].set_visible(False)
ax5.spines['bottom'].set_visible(False)
ax5.spines['left'].set_visible(False)
ax5.xaxis.set_major_formatter(currency)
ax5.tick_params(axis='x', which='major', labelsize=12)
ax5.legend(title=None) 


#ax6 = Top Taux de retour --> cette fois on applique la fonction sur df et non sur df_complete puisque nécessaire pour le calcul du taux de retour
top_TR_State=kpi_tx_retour(df, ['state'])
top_TR_State = top_TR_State.sort_values(by='taux_retour', ascending=False)
top_TR_State = top_TR_State.set_index('state')
top_TR_State.plot(kind='barh', color="#FF934F", ax=ax6)
ax6.set_xlim(0, top_TR_State['taux_retour'].max() * 1.1)

#ajout d'une barre pour montrer la valeur mediane du taux de retour:
median_TR = top_TR_State['taux_retour'].median()
ax6.axvline(x=median_TR, color='red', linestyle='--', linewidth=2, label=f"Médiane : {median_TR*100:.1f}%")  # affichée en %

ax6.set_title("Classement décroissant des Régions par taux de retour \n sur l'ensemble de la période")
ax6.set_xlabel("Taux de retour (%)")
ax6.set_ylabel("Région")

#Formattage du graphique 
ax6.grid(visible=True, which='major', axis='x')
ax6.spines['top'].set_visible(False)
ax6.spines['right'].set_visible(False)
ax6.spines['bottom'].set_visible(False)
ax6.spines['left'].set_visible(False)
ax6.tick_params(axis='x', which='major', labelsize=12)
ax6.legend(title=None)
ax6.xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1)) # permet d'avoir l'axe des x en %

#ax7 : Poids des category par region
ca_month_State = kpi_CA(df_complete,['category', 'state'])
pivot_ca = ca_month_State.pivot(index='category',columns='state', values='chiffre_affaires').fillna(0)
pivot_ca = pivot_ca.sort_index()
pivot_heatmap = ca_month_State.pivot(index='state', columns='category', values='chiffre_affaires').fillna(0)
total_ca = pivot_heatmap.sum(axis=1)
pivot_heatmap_sorted = pivot_heatmap.loc[total_ca.sort_values(ascending=False).index]

sns.heatmap(pivot_heatmap_sorted, cmap="YlGnBu", linewidths=0.5, annot=True, fmt=".0f", ax=ax7)
ax7.set_title("Chiffre d'affaires sur l'ensemble de la période - Poids des catégories par Région")
ax7.set_xlabel("Category")
ax7.set_ylabel("Région")

#Formattage du graphique 

ax7.spines['top'].set_visible(False)
ax7.spines['right'].set_visible(False)
ax7.spines['bottom'].set_visible(False)
ax7.spines['left'].set_visible(False)

plt.tight_layout() #ajuste automatiquement les marges

# %% [markdown]
# #### ZOOM SUR LES VILLES

# %%
fig = plt.figure(constrained_layout=False, figsize = (20,12))
gs = fig.add_gridspec(1, 2)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

# Premier Graphique : Top des villes par CA avec décomposition par catégorie
# CA par ville + catégorie
top_CA_City_cat = kpi_CA(df_complete, ['city', 'category'])
# Pivot : catégories en colonnes
top_CA_City_cat = (top_CA_City_cat.pivot(index='city', columns='category', values='chiffre_affaires').fillna(0))
# CA total
top_CA_City_cat["CA_total"] = top_CA_City_cat.sum(axis=1)
# TOP 10 décroissant
top_city = (top_CA_City_cat.sort_values("CA_total", ascending=False).head(10))
# classement en ordre croissant du top 10 pour le graphique
top_citys = top_city.sort_values("CA_total", ascending=True)
# supprimer CA_total sans casser l'ordre -> obligé pour avoir el graphique correctement affché
top_citys = top_citys.drop(columns="CA_total")

# Graphique
n_cat = len(top_citys.columns)
colors = cm.tab20(np.linspace(0, 1, n_cat)) #création d'une palette de couleurs distinctes pour chaque category
top_citys.plot(kind='barh', stacked=True, ax=ax1,color=colors)
ax1.legend(title="Catégorie")
ax1.set_title("Top 10 des villes à plus fort Chiffre d'Affaires sur 2023-2024 \n Décomposition par catégorie")

#format du grpahique 

ax1.grid(visible=True, which='major', axis='x')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.set_xlim(0, 1000) # force les limites de l'axe x
ax1.xaxis.set_major_formatter(currency)
ax1.tick_params(axis='x', which='major', labelsize=12)
ax1.legend(title=None)


#Second graphique : Proportion du CA 2024 sur les nouvelles villes

#Définission la liste des nouelles villes (CA en 2024 mais pas en 2023)
cities_2024 = df_complete[df_complete['year_created'] == 2024]['city'].unique()
cities_2023 = df_complete[df_complete['year_created'] == 2023]['city'].unique()
new_cities = list(set(cities_2024) - set(cities_2023))  # nouvelles villes

#On calcule le CA selon nouvelles villes (CA en 2024 uniquement) et villes pour lesquelles on avait déjà du CA en 2023
df_complete['city_type'] = df_complete['city'].apply(lambda x: 'Nouvelles villes' if x in new_cities else 'Villes déjà ciblées')

# CA total par type
#CA_by_city_type = df_complete.groupby('city_type')['sale_price'].sum()

CA_by_city_type = kpi_CA(df_complete, dimensions=['city_type'])

#graphique :
CA_by_city_type.plot(kind='pie',y="chiffre_affaires", labels=CA_by_city_type['city_type'], autopct='%1.1f%%',colors=['#075594', '#95b2c9'],ax=ax2)
ax2.set_title("Pourcentage du Chiffre d'Affaires 2024 par type de ville \n (nouvelles VS déjà ciblées en 2023)")


plt.tight_layout() #ajuste automatiquement les marges
# Out:
# C:\Users\chd78002\AppData\Local\Temp\ipykernel_20560\2201147721.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_complete['city_type'] = df_complete['city'].apply(lambda x: 'Nouvelles villes' if x in new_cities else 'Villes déjà ciblées')

# %% [markdown]
# ### ANALYSE PAR BRAND

# %%
fig = plt.figure(constrained_layout=False, figsize = (20,12))
gs = fig.add_gridspec(1, 2)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

# CA par brand + catégorie
top_CA_Brand_cat = kpi_CA(df_complete, ['brand', 'category'])
# Pivot : catégories en colonnes
top_CA_Brand_cat = (top_CA_Brand_cat.pivot(index='brand', columns='category', values='chiffre_affaires').fillna(0))
# CA total
top_CA_Brand_cat["CA_total"] = top_CA_Brand_cat.sum(axis=1)
# TOP 10 décroissant
top_brand = (top_CA_Brand_cat.sort_values("CA_total", ascending=False).head(20))
# classement en ordre croissant du top 10 pour le graphique
top_brand = top_brand.sort_values("CA_total", ascending=True)
# supprimer CA_total sans casser l'ordre -> obligé pour avoir el graphique correctement affché
top_brand = top_brand.drop(columns="CA_total")

# Graphique
n_cat = len(top_brand.columns)
colors = cm.tab20(np.linspace(0, 1, n_cat)) #création d'une palette de couleurs distinctes pour chaque category
top_brand.plot(kind='barh', stacked=True, ax=ax1,color=colors)
ax1.legend(title="Catégorie")
ax1.set_title("Top 10 des marques à plus fort Chiffre d'Affaires sur 2023-2024 \n Décomposition par catégorie")

#format du grpahique 

ax1.grid(visible=True, which='major', axis='x')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.set_xlim(0, 1300) # force les limites de l'axe x
ax1.xaxis.set_major_formatter(currency)
ax1.tick_params(axis='x', which='major', labelsize=12)
ax1.legend(title=None)


#second graphique : Top Brand par taux de marge (marge / Chiffre d'affaires). on veut garder les mêmes brands que dans le premier graphique

#on récupère les brands qui nous intéresse (définies dans premier graphique):
brand_order = top_brand.index.tolist()

#on calcule d'abord marge et CA individuellement
CA_brand = kpi_CA(df_complete, ['brand'])
margin_brand = kpi_Margin(df_complete, ['brand'])
#On fusionne les 2
df_brand = CA_brand.merge(margin_brand, on='brand')


#calcul du taux de marge :
df_brand['taux_marge'] = df_brand['marge'] / df_brand['chiffre_affaires']
df_brand = df_brand[df_brand['chiffre_affaires'] > 0] #sécurité si on a un CA <0 ou =0


#on fait un ranking sur le taux_marge puis on garde le top10
top_margin_brand = (df_brand.set_index('brand').loc[brand_order][['taux_marge']])


#graphique top 
top_margin_brand.plot(kind='barh',ax=ax2,color='#075594',legend=False)

#on ajoute la moyenne du taux de marge 
taux_marge_median = df_brand['taux_marge'].median()

ax2.axvline(x=taux_marge_median,color='red',linestyle='--',linewidth=2,label='Taux de marge median')

ax2.set_title("Taux de marge du Top 10 des marques ")
ax2.set_xlabel("Taux de marge")
ax2.xaxis.set_major_formatter(lambda x, _: f"{x:.0%}")
ax2.legend(title=None)




plt.tight_layout() #ajuste automatiquement les marges

# %%
top_category=kpi_CA(df_complete, ['category'])
top_category = top_category.sort_values(by='chiffre_affaires', ascending=True)
top_category = top_category.set_index('category')
top_category.plot(kind='barh', figsize=(8,6))
plt.title("Classement des categories par chiffre d'affaire sur l'ensemble de la période")
plt.xlabel("Chiffre d'Affaires")
plt.ylabel("Catégorie")
plt.show()

# %%
# Création du pivot des chiffres d'affaires sur df_complete (order "Complete" + exclusion de 2025), on passe en pivot et on traite les éventuelles valeurs N/A (même s'il n'y en a pas a priori)
top_cat_year_pivot = (kpi_CA(df_complete, ['category', "year_created"]).pivot(index='category', columns='year_created', values='chiffre_affaires').fillna(0))

#Calcul de la croissance 2024 vs 2023
growth = top_cat_year_pivot[2024] - top_cat_year_pivot[2023]

# Tri décroissant par growth en valeur absolue
top_cat_year_pivot_sorted = top_cat_year_pivot.loc[growth.sort_values(ascending=False).index]

#Tracer le bar histogramme
colors = ['#95b2c9', '#075594']
ax1=top_cat_year_pivot_sorted.plot(kind='barh', figsize=(10,7), color=colors)

# on trace la ligne rouge qui délimite le growth négatif
negative_growth = growth.sort_values(ascending=False) # trie le growth en décroissant
if (negative_growth < 0).any(): # crée une série booléenne indiquant quelles catégories ont une croissance négative, renvoie True si au moisn une est négative
    first_negative_cat = negative_growth[negative_growth < 0].index[0]  # prend la première catégorie dans la série triée qui a une croissance négative.
    y_position = top_cat_year_pivot_sorted.index.get_loc(first_negative_cat) - 0.5 # -0.5 car décale la ligne de 0,5 pour qu’elle soit entre les barres et pas par-dessus
    plt.axhline(y=y_position, color='red', linestyle='--', linewidth=2, label='Growth négatif') # trace la ligne

# Labels et titre
plt.title("Top catégories – croissance du Chiffre d'affaires 2024 vs 2023")
plt.xlabel("Chiffre d'affaires")
plt.ylabel("Catégories")
plt.gca().invert_yaxis()  # catégorie la plus haute en haut
ax1.xaxis.set_major_formatter(currency)

plt.tight_layout()
plt.show()

# %%
top_brands = df.groupby('brand')['sale_price'].sum().sort_values(ascending=True).head(20)
top_brands.plot(kind='barh', figsize=(8,6), color='skyblue')
plt.title("Top marques par ventes")
plt.xlabel("Total ventes")
plt.show()

# %%
#CREATION DU GRAPHIQUE VUE MENSUELLE PAR CATEGORIE
#Calcul du KPI par categorie et classement
ca_month_category = kpi_CA(df_complete,['year_month', 'category'])
pivot_ca = ca_month_category.pivot(index='year_month',columns='category', values='chiffre_affaires').fillna(0)
pivot_ca = pivot_ca.sort_index()



#Comme on a 21 categories, on ne peut pas tout garder sur le graphique.
#on se concentre sur un Top  + les autres catégories classées dans "Autres"
top_categories = pivot_ca.sum().sort_values(ascending=False).head(5).index
# Séparer les Top et les autres
pivot_top = pivot_ca[top_categories]  # Top 5
pivot_other = pivot_ca.drop(columns=top_categories).sum(axis=1)  # Somme des autres
# Ajouter "Autres" comme colonne
pivot_ca_grouped = pivot_top.copy()
pivot_ca_grouped['Autres'] = pivot_other

colors_top = sns.color_palette("tab10", n_colors=5)  # couleurs automatiques
colors = list(colors_top) + ["lightgrey"]


pivot_ca_grouped.plot(kind='line', stacked=True,  figsize=(12, 7),color=colors)
plt.title("Chiffre d'affaires mensuel par catégorie (Top 5 + Autres)")
plt.xlabel("Mois")
plt.ylabel("Chiffre d'affaires")
plt.legend(title="Catégorie", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
pivot_heatmap = ca_month_category.pivot(index='category', columns='year_month', values='chiffre_affaires').fillna(0)
total_ca = pivot_heatmap.sum(axis=1)
pivot_heatmap_sorted = pivot_heatmap.loc[total_ca.sort_values(ascending=False).index]
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_heatmap_sorted, cmap="YlGnBu", linewidths=0.5, annot=True, fmt=".0f")
plt.title("Saisonnalité du chiffre d'affaires par catégorie")
plt.xlabel("Mois")
plt.ylabel("Catégorie")
plt.show()
